# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 1
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 1:
# Image - Min Value: 15 Max Value: 249
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    #By exploring the data, I learned that the lowest value was 0 and the highest was 255
    return (x-0)/(255-0)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
        
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    return np.eye(10)[x]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, *image_shape], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    color_channels = x_tensor.get_shape().as_list()[3]
    strides = [1, conv_strides[0], conv_strides[1], 1]
    kstrides = [1, pool_ksize[0], pool_ksize[1], 1]
    pstrides = [1, pool_strides[0], pool_strides[1], 1]
    
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], color_channels, conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    x_tensor = tf.nn.conv2d(x_tensor, weights, strides, padding='SAME')
    x_tensor = tf.nn.bias_add(x_tensor, bias)
    x_tensor = tf.nn.relu(x_tensor)
    x_tensor = tf.nn.max_pool(x_tensor, kstrides, pstrides, padding='SAME')
    return x_tensor

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, tf.nn.relu)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn= None)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    num_output = 10 #10 labels
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    layer_1 = conv2d_maxpool(x, 10, (2, 2), (2, 2), (2, 2), (2, 2))
    #layer_2 = conv2d_maxpool(layer_1, 10, (2, 2), (2, 2), (2, 2), (2, 2))
    #layer_3 = conv2d_maxpool(layer_2, 10, (2, 2), (2, 2), (2, 2), (2, 2))


    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    flatten_layer = flatten(layer_1)
    #flatten_layer = tf.nn.dropout(flatten_layer, keep_prob)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    fully_con_layer = fully_conn(flatten_layer, num_output*10)
    fully_con_layer = tf.nn.dropout(fully_con_layer, keep_prob)   
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(fully_con_layer, num_output)
    
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    validation_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.})
    
    print('Loss: {:.4f} Validation Accuracy: {:.6f}%'.format(loss, validation_accuracy*100))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 1200
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.3261 Validation Accuracy: 16.480000%
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.2228 Validation Accuracy: 18.760000%
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.1737 Validation Accuracy: 21.680000%
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.1273 Validation Accuracy: 23.620000%
# Epoch  5, CIFAR-10 Batch 1:  Loss: 2.0977 Validation Accuracy: 25.360000%
# Epoch  6, CIFAR-10 Batch 1:  Loss: 2.0645 Validation Accuracy: 25.940001%
# Epoch  7, CIFAR-10 Batch 1:  Loss: 2.0320 Validation Accuracy: 28.099999%
# Epoch  8, CIFAR-10 Batch 1:  Loss: 2.0028 Validation Accuracy: 29.440001%
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.9702 Validation Accuracy: 30.960000%
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.9416 Validation Accuracy: 33.120000%
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.9073 Validation Accuracy: 34.439999%
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.8790 Validation Accuracy: 34.740001%
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.8501 Validation Accuracy: 36.620000%
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.8113 Validation Accuracy: 37.020001%
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.7800 Validation Accuracy: 38.580000%
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.7603 Validation Accuracy: 38.940001%
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.7256 Validation Accuracy: 39.919999%
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.7062 Validation Accuracy: 40.099999%
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.6768 Validation Accuracy: 40.419999%
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.6681 Validation Accuracy: 41.900000%
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.6370 Validation Accuracy: 41.600001%
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.6112 Validation Accuracy: 42.519999%
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.6044 Validation Accuracy: 42.100000%
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.5746 Validation Accuracy: 42.760000%
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.5615 Validation Accuracy: 43.200001%
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.5436 Validation Accuracy: 43.560001%
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.5129 Validation Accuracy: 43.740001%
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.5044 Validation Accuracy: 43.860000%
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.4860 Validation Accuracy: 44.119999%
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.4722 Validation Accuracy: 45.060000%
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.4564 Validation Accuracy: 44.319999%
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.4361 Validation Accuracy: 45.179999%
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.4179 Validation Accuracy: 45.780000%
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.4040 Validation Accuracy: 45.760000%
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.3952 Validation Accuracy: 46.000001%
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.3748 Validation Accuracy: 46.280000%
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.3704 Validation Accuracy: 46.599999%
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.3524 Validation Accuracy: 46.860000%
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.3427 Validation Accuracy: 46.779999%
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.3255 Validation Accuracy: 46.959999%
# Epoch 41, CIFAR-10 Batch 1:  Loss: 1.3217 Validation Accuracy: 47.400001%
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.3027 Validation Accuracy: 47.279999%
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.2941 Validation Accuracy: 47.720000%
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.2858 Validation Accuracy: 47.720000%
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.2699 Validation Accuracy: 47.700000%
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.2744 Validation Accuracy: 47.760001%
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.2513 Validation Accuracy: 48.320001%
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.2436 Validation Accuracy: 48.379999%
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.2387 Validation Accuracy: 47.979999%
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.2290 Validation Accuracy: 48.280001%
# Epoch 51, CIFAR-10 Batch 1:  Loss: 1.2202 Validation Accuracy: 48.159999%
# Epoch 52, CIFAR-10 Batch 1:  Loss: 1.2138 Validation Accuracy: 48.879999%
# Epoch 53, CIFAR-10 Batch 1:  Loss: 1.2124 Validation Accuracy: 48.820001%
# Epoch 54, CIFAR-10 Batch 1:  Loss: 1.1896 Validation Accuracy: 48.640001%
# Epoch 55, CIFAR-10 Batch 1:  Loss: 1.1886 Validation Accuracy: 49.120000%
# Epoch 56, CIFAR-10 Batch 1:  Loss: 1.1769 Validation Accuracy: 48.600000%
# Epoch 57, CIFAR-10 Batch 1:  Loss: 1.1681 Validation Accuracy: 49.140000%
# Epoch 58, CIFAR-10 Batch 1:  Loss: 1.1676 Validation Accuracy: 49.559999%
# Epoch 59, CIFAR-10 Batch 1:  Loss: 1.1488 Validation Accuracy: 49.480000%
# Epoch 60, CIFAR-10 Batch 1:  Loss: 1.1463 Validation Accuracy: 49.559999%
# Epoch 61, CIFAR-10 Batch 1:  Loss: 1.1372 Validation Accuracy: 49.020001%
# Epoch 62, CIFAR-10 Batch 1:  Loss: 1.1308 Validation Accuracy: 49.520001%
# Epoch 63, CIFAR-10 Batch 1:  Loss: 1.1202 Validation Accuracy: 49.720001%
# Epoch 64, CIFAR-10 Batch 1:  Loss: 1.1127 Validation Accuracy: 49.579999%
# Epoch 65, CIFAR-10 Batch 1:  Loss: 1.1011 Validation Accuracy: 49.779999%
# Epoch 66, CIFAR-10 Batch 1:  Loss: 1.0996 Validation Accuracy: 49.259999%
# Epoch 67, CIFAR-10 Batch 1:  Loss: 1.0879 Validation Accuracy: 50.199997%
# Epoch 68, CIFAR-10 Batch 1:  Loss: 1.0844 Validation Accuracy: 50.160003%
# Epoch 69, CIFAR-10 Batch 1:  Loss: 1.0705 Validation Accuracy: 49.900001%
# Epoch 70, CIFAR-10 Batch 1:  Loss: 1.0676 Validation Accuracy: 50.340003%
# Epoch 71, CIFAR-10 Batch 1:  Loss: 1.0683 Validation Accuracy: 50.400001%
# Epoch 72, CIFAR-10 Batch 1:  Loss: 1.0498 Validation Accuracy: 50.120002%
# Epoch 73, CIFAR-10 Batch 1:  Loss: 1.0440 Validation Accuracy: 50.800002%
# Epoch 74, CIFAR-10 Batch 1:  Loss: 1.0371 Validation Accuracy: 51.099998%
# Epoch 75, CIFAR-10 Batch 1:  Loss: 1.0391 Validation Accuracy: 50.700003%
# Epoch 76, CIFAR-10 Batch 1:  Loss: 1.0242 Validation Accuracy: 50.680000%
# Epoch 77, CIFAR-10 Batch 1:  Loss: 1.0199 Validation Accuracy: 50.419998%
# Epoch 78, CIFAR-10 Batch 1:  Loss: 1.0153 Validation Accuracy: 50.739998%
# Epoch 79, CIFAR-10 Batch 1:  Loss: 1.0081 Validation Accuracy: 51.139998%
# Epoch 80, CIFAR-10 Batch 1:  Loss: 0.9982 Validation Accuracy: 50.999999%
# Epoch 81, CIFAR-10 Batch 1:  Loss: 0.9996 Validation Accuracy: 51.539999%
# Epoch 82, CIFAR-10 Batch 1:  Loss: 0.9863 Validation Accuracy: 51.160002%
# Epoch 83, CIFAR-10 Batch 1:  Loss: 0.9810 Validation Accuracy: 51.260000%
# Epoch 84, CIFAR-10 Batch 1:  Loss: 0.9763 Validation Accuracy: 51.359999%
# Epoch 85, CIFAR-10 Batch 1:  Loss: 0.9689 Validation Accuracy: 51.059997%
# Epoch 86, CIFAR-10 Batch 1:  Loss: 0.9609 Validation Accuracy: 51.260000%
# Epoch 87, CIFAR-10 Batch 1:  Loss: 0.9601 Validation Accuracy: 51.179999%
# Epoch 88, CIFAR-10 Batch 1:  Loss: 0.9467 Validation Accuracy: 51.220000%
# Epoch 89, CIFAR-10 Batch 1:  Loss: 0.9444 Validation Accuracy: 51.419997%
# Epoch 90, CIFAR-10 Batch 1:  Loss: 0.9363 Validation Accuracy: 51.679999%
# Epoch 91, CIFAR-10 Batch 1:  Loss: 0.9262 Validation Accuracy: 51.040000%
# Epoch 92, CIFAR-10 Batch 1:  Loss: 0.9275 Validation Accuracy: 52.179998%
# Epoch 93, CIFAR-10 Batch 1:  Loss: 0.9187 Validation Accuracy: 51.520002%
# Epoch 94, CIFAR-10 Batch 1:  Loss: 0.9111 Validation Accuracy: 52.079999%
# Epoch 95, CIFAR-10 Batch 1:  Loss: 0.9142 Validation Accuracy: 52.100003%
# Epoch 96, CIFAR-10 Batch 1:  Loss: 0.9035 Validation Accuracy: 51.220000%
# Epoch 97, CIFAR-10 Batch 1:  Loss: 0.9037 Validation Accuracy: 51.800001%
# Epoch 98, CIFAR-10 Batch 1:  Loss: 0.8841 Validation Accuracy: 52.139997%
# Epoch 99, CIFAR-10 Batch 1:  Loss: 0.8925 Validation Accuracy: 51.880002%
# Epoch 100, CIFAR-10 Batch 1:  Loss: 0.8801 Validation Accuracy: 51.999998%
# Epoch 101, CIFAR-10 Batch 1:  Loss: 0.8861 Validation Accuracy: 51.940000%
# Epoch 102, CIFAR-10 Batch 1:  Loss: 0.8732 Validation Accuracy: 51.940000%
# Epoch 103, CIFAR-10 Batch 1:  Loss: 0.8738 Validation Accuracy: 52.039999%
# Epoch 104, CIFAR-10 Batch 1:  Loss: 0.8623 Validation Accuracy: 52.380002%
# Epoch 105, CIFAR-10 Batch 1:  Loss: 0.8520 Validation Accuracy: 52.020001%
# Epoch 106, CIFAR-10 Batch 1:  Loss: 0.8630 Validation Accuracy: 52.300000%
# Epoch 107, CIFAR-10 Batch 1:  Loss: 0.8537 Validation Accuracy: 51.959997%
# Epoch 108, CIFAR-10 Batch 1:  Loss: 0.8503 Validation Accuracy: 52.079999%
# Epoch 109, CIFAR-10 Batch 1:  Loss: 0.8369 Validation Accuracy: 52.100003%
# Epoch 110, CIFAR-10 Batch 1:  Loss: 0.8270 Validation Accuracy: 52.039999%
# Epoch 111, CIFAR-10 Batch 1:  Loss: 0.8208 Validation Accuracy: 51.999998%
# Epoch 112, CIFAR-10 Batch 1:  Loss: 0.8235 Validation Accuracy: 51.999998%
# Epoch 113, CIFAR-10 Batch 1:  Loss: 0.8160 Validation Accuracy: 52.340001%
# Epoch 114, CIFAR-10 Batch 1:  Loss: 0.8160 Validation Accuracy: 51.980001%
# Epoch 115, CIFAR-10 Batch 1:  Loss: 0.8068 Validation Accuracy: 52.359998%
# Epoch 116, CIFAR-10 Batch 1:  Loss: 0.7959 Validation Accuracy: 52.319998%
# Epoch 117, CIFAR-10 Batch 1:  Loss: 0.7956 Validation Accuracy: 52.460003%
# Epoch 118, CIFAR-10 Batch 1:  Loss: 0.7955 Validation Accuracy: 52.560002%
# Epoch 119, CIFAR-10 Batch 1:  Loss: 0.7832 Validation Accuracy: 52.560002%
# Epoch 120, CIFAR-10 Batch 1:  Loss: 0.7948 Validation Accuracy: 52.100003%
# Epoch 121, CIFAR-10 Batch 1:  Loss: 0.7813 Validation Accuracy: 52.219999%
# Epoch 122, CIFAR-10 Batch 1:  Loss: 0.7764 Validation Accuracy: 52.560002%
# Epoch 123, CIFAR-10 Batch 1:  Loss: 0.7767 Validation Accuracy: 52.440000%
# Epoch 124, CIFAR-10 Batch 1:  Loss: 0.7714 Validation Accuracy: 52.219999%
# Epoch 125, CIFAR-10 Batch 1:  Loss: 0.7608 Validation Accuracy: 52.560002%
# Epoch 126, CIFAR-10 Batch 1:  Loss: 0.7540 Validation Accuracy: 52.579999%
# Epoch 127, CIFAR-10 Batch 1:  Loss: 0.7519 Validation Accuracy: 52.280003%
# Epoch 128, CIFAR-10 Batch 1:  Loss: 0.7551 Validation Accuracy: 52.700001%
# Epoch 129, CIFAR-10 Batch 1:  Loss: 0.7328 Validation Accuracy: 52.759999%
# Epoch 130, CIFAR-10 Batch 1:  Loss: 0.7394 Validation Accuracy: 52.499998%
# Epoch 131, CIFAR-10 Batch 1:  Loss: 0.7322 Validation Accuracy: 52.939999%
# Epoch 132, CIFAR-10 Batch 1:  Loss: 0.7267 Validation Accuracy: 52.740002%
# Epoch 133, CIFAR-10 Batch 1:  Loss: 0.7302 Validation Accuracy: 52.679998%
# Epoch 134, CIFAR-10 Batch 1:  Loss: 0.7243 Validation Accuracy: 52.759999%
# Epoch 135, CIFAR-10 Batch 1:  Loss: 0.7179 Validation Accuracy: 52.840000%
# Epoch 136, CIFAR-10 Batch 1:  Loss: 0.7171 Validation Accuracy: 52.660000%
# Epoch 137, CIFAR-10 Batch 1:  Loss: 0.7052 Validation Accuracy: 52.359998%
# Epoch 138, CIFAR-10 Batch 1:  Loss: 0.7115 Validation Accuracy: 52.499998%
# Epoch 139, CIFAR-10 Batch 1:  Loss: 0.7117 Validation Accuracy: 52.319998%
# Epoch 140, CIFAR-10 Batch 1:  Loss: 0.7046 Validation Accuracy: 52.819997%
# Epoch 141, CIFAR-10 Batch 1:  Loss: 0.6969 Validation Accuracy: 52.640003%
# Epoch 142, CIFAR-10 Batch 1:  Loss: 0.6926 Validation Accuracy: 52.380002%
# Epoch 143, CIFAR-10 Batch 1:  Loss: 0.6829 Validation Accuracy: 52.460003%
# Epoch 144, CIFAR-10 Batch 1:  Loss: 0.6824 Validation Accuracy: 52.280003%
# Epoch 145, CIFAR-10 Batch 1:  Loss: 0.6738 Validation Accuracy: 52.499998%
# Epoch 146, CIFAR-10 Batch 1:  Loss: 0.6895 Validation Accuracy: 52.700001%
# Epoch 147, CIFAR-10 Batch 1:  Loss: 0.6613 Validation Accuracy: 52.620000%
# Epoch 148, CIFAR-10 Batch 1:  Loss: 0.6766 Validation Accuracy: 52.579999%
# Epoch 149, CIFAR-10 Batch 1:  Loss: 0.6577 Validation Accuracy: 52.700001%
# Epoch 150, CIFAR-10 Batch 1:  Loss: 0.6638 Validation Accuracy: 52.359998%
# Epoch 151, CIFAR-10 Batch 1:  Loss: 0.6488 Validation Accuracy: 52.399999%
# Epoch 152, CIFAR-10 Batch 1:  Loss: 0.6575 Validation Accuracy: 52.960002%
# Epoch 153, CIFAR-10 Batch 1:  Loss: 0.6392 Validation Accuracy: 53.179997%
# Epoch 154, CIFAR-10 Batch 1:  Loss: 0.6605 Validation Accuracy: 52.280003%
# Epoch 155, CIFAR-10 Batch 1:  Loss: 0.6406 Validation Accuracy: 52.539998%
# Epoch 156, CIFAR-10 Batch 1:  Loss: 0.6456 Validation Accuracy: 52.880001%
# Epoch 157, CIFAR-10 Batch 1:  Loss: 0.6390 Validation Accuracy: 52.819997%
# Epoch 158, CIFAR-10 Batch 1:  Loss: 0.6384 Validation Accuracy: 52.880001%
# Epoch 159, CIFAR-10 Batch 1:  Loss: 0.6366 Validation Accuracy: 52.800000%
# Epoch 160, CIFAR-10 Batch 1:  Loss: 0.6279 Validation Accuracy: 52.359998%
# Epoch 161, CIFAR-10 Batch 1:  Loss: 0.6390 Validation Accuracy: 53.020000%
# Epoch 162, CIFAR-10 Batch 1:  Loss: 0.6178 Validation Accuracy: 52.740002%
# Epoch 163, CIFAR-10 Batch 1:  Loss: 0.6224 Validation Accuracy: 52.700001%
# Epoch 164, CIFAR-10 Batch 1:  Loss: 0.6194 Validation Accuracy: 52.819997%
# Epoch 165, CIFAR-10 Batch 1:  Loss: 0.6102 Validation Accuracy: 52.719998%
# Epoch 166, CIFAR-10 Batch 1:  Loss: 0.6076 Validation Accuracy: 52.679998%
# Epoch 167, CIFAR-10 Batch 1:  Loss: 0.6092 Validation Accuracy: 53.160000%
# Epoch 168, CIFAR-10 Batch 1:  Loss: 0.6056 Validation Accuracy: 52.640003%
# Epoch 169, CIFAR-10 Batch 1:  Loss: 0.5980 Validation Accuracy: 52.620000%
# Epoch 170, CIFAR-10 Batch 1:  Loss: 0.5952 Validation Accuracy: 52.840000%
# Epoch 171, CIFAR-10 Batch 1:  Loss: 0.5906 Validation Accuracy: 52.700001%
# Epoch 172, CIFAR-10 Batch 1:  Loss: 0.5818 Validation Accuracy: 52.920002%
# Epoch 173, CIFAR-10 Batch 1:  Loss: 0.5866 Validation Accuracy: 52.740002%
# Epoch 174, CIFAR-10 Batch 1:  Loss: 0.5774 Validation Accuracy: 52.920002%
# Epoch 175, CIFAR-10 Batch 1:  Loss: 0.5825 Validation Accuracy: 52.620000%
# Epoch 176, CIFAR-10 Batch 1:  Loss: 0.5781 Validation Accuracy: 52.539998%
# Epoch 177, CIFAR-10 Batch 1:  Loss: 0.5800 Validation Accuracy: 52.079999%
# Epoch 178, CIFAR-10 Batch 1:  Loss: 0.5630 Validation Accuracy: 52.260000%
# Epoch 179, CIFAR-10 Batch 1:  Loss: 0.5727 Validation Accuracy: 52.300000%
# Epoch 180, CIFAR-10 Batch 1:  Loss: 0.5670 Validation Accuracy: 53.079998%
# Epoch 181, CIFAR-10 Batch 1:  Loss: 0.5692 Validation Accuracy: 52.359998%
# Epoch 182, CIFAR-10 Batch 1:  Loss: 0.5470 Validation Accuracy: 52.740002%
# Epoch 183, CIFAR-10 Batch 1:  Loss: 0.5569 Validation Accuracy: 53.100002%
# Epoch 184, CIFAR-10 Batch 1:  Loss: 0.5542 Validation Accuracy: 52.700001%
# Epoch 185, CIFAR-10 Batch 1:  Loss: 0.5491 Validation Accuracy: 52.660000%
# Epoch 186, CIFAR-10 Batch 1:  Loss: 0.5489 Validation Accuracy: 52.539998%
# Epoch 187, CIFAR-10 Batch 1:  Loss: 0.5512 Validation Accuracy: 52.759999%
# Epoch 188, CIFAR-10 Batch 1:  Loss: 0.5414 Validation Accuracy: 52.480000%
# Epoch 189, CIFAR-10 Batch 1:  Loss: 0.5423 Validation Accuracy: 52.499998%
# Epoch 190, CIFAR-10 Batch 1:  Loss: 0.5290 Validation Accuracy: 52.880001%
# Epoch 191, CIFAR-10 Batch 1:  Loss: 0.5294 Validation Accuracy: 52.759999%
# Epoch 192, CIFAR-10 Batch 1:  Loss: 0.5342 Validation Accuracy: 52.480000%
# Epoch 193, CIFAR-10 Batch 1:  Loss: 0.5296 Validation Accuracy: 52.960002%
# Epoch 194, CIFAR-10 Batch 1:  Loss: 0.5246 Validation Accuracy: 52.780002%
# Epoch 195, CIFAR-10 Batch 1:  Loss: 0.5189 Validation Accuracy: 52.840000%
# Epoch 196, CIFAR-10 Batch 1:  Loss: 0.5176 Validation Accuracy: 52.700001%
# Epoch 197, CIFAR-10 Batch 1:  Loss: 0.5055 Validation Accuracy: 53.020000%
# Epoch 198, CIFAR-10 Batch 1:  Loss: 0.5105 Validation Accuracy: 52.700001%
# Epoch 199, CIFAR-10 Batch 1:  Loss: 0.5135 Validation Accuracy: 52.980000%
# Epoch 200, CIFAR-10 Batch 1:  Loss: 0.5131 Validation Accuracy: 53.079998%

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.3444 Validation Accuracy: 14.980000%
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.2317 Validation Accuracy: 18.940000%
# Epoch  1, CIFAR-10 Batch 3:  Loss: 2.2170 Validation Accuracy: 18.460000%
# Epoch  1, CIFAR-10 Batch 4:  Loss: 2.1906 Validation Accuracy: 20.119999%
# Epoch  1, CIFAR-10 Batch 5:  Loss: 2.1494 Validation Accuracy: 20.760000%
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.1319 Validation Accuracy: 25.380000%
# Epoch  2, CIFAR-10 Batch 2:  Loss: 2.1073 Validation Accuracy: 26.519999%
# Epoch  2, CIFAR-10 Batch 3:  Loss: 2.0414 Validation Accuracy: 26.640001%
# Epoch  2, CIFAR-10 Batch 4:  Loss: 2.0387 Validation Accuracy: 27.840000%
# Epoch  2, CIFAR-10 Batch 5:  Loss: 2.0125 Validation Accuracy: 29.920000%
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1.9887 Validation Accuracy: 30.399999%
# Epoch  3, CIFAR-10 Batch 2:  Loss: 1.9659 Validation Accuracy: 32.720000%
# Epoch  3, CIFAR-10 Batch 3:  Loss: 1.8971 Validation Accuracy: 33.419999%
# Epoch  3, CIFAR-10 Batch 4:  Loss: 1.8771 Validation Accuracy: 34.720001%
# Epoch  3, CIFAR-10 Batch 5:  Loss: 1.8833 Validation Accuracy: 34.360000%
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.8571 Validation Accuracy: 35.820001%
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1.8301 Validation Accuracy: 36.399999%
# Epoch  4, CIFAR-10 Batch 3:  Loss: 1.7746 Validation Accuracy: 37.439999%
# Epoch  4, CIFAR-10 Batch 4:  Loss: 1.7605 Validation Accuracy: 37.619999%
# Epoch  4, CIFAR-10 Batch 5:  Loss: 1.7714 Validation Accuracy: 37.740001%
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.7799 Validation Accuracy: 38.600001%
# Epoch  5, CIFAR-10 Batch 2:  Loss: 1.7571 Validation Accuracy: 38.280001%
# Epoch  5, CIFAR-10 Batch 3:  Loss: 1.6920 Validation Accuracy: 39.399999%
# Epoch  5, CIFAR-10 Batch 4:  Loss: 1.6919 Validation Accuracy: 39.199999%
# Epoch  5, CIFAR-10 Batch 5:  Loss: 1.7074 Validation Accuracy: 39.280000%
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.7304 Validation Accuracy: 40.979999%
# Epoch  6, CIFAR-10 Batch 2:  Loss: 1.6927 Validation Accuracy: 40.660000%
# Epoch  6, CIFAR-10 Batch 3:  Loss: 1.6472 Validation Accuracy: 40.520000%
# Epoch  6, CIFAR-10 Batch 4:  Loss: 1.6471 Validation Accuracy: 40.619999%
# Epoch  6, CIFAR-10 Batch 5:  Loss: 1.6604 Validation Accuracy: 40.700001%
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.6908 Validation Accuracy: 41.280001%
# Epoch  7, CIFAR-10 Batch 2:  Loss: 1.6611 Validation Accuracy: 41.760001%
# Epoch  7, CIFAR-10 Batch 3:  Loss: 1.5984 Validation Accuracy: 41.440001%
# Epoch  7, CIFAR-10 Batch 4:  Loss: 1.6012 Validation Accuracy: 41.740000%
# Epoch  7, CIFAR-10 Batch 5:  Loss: 1.6275 Validation Accuracy: 42.019999%
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.6489 Validation Accuracy: 42.420000%
# Epoch  8, CIFAR-10 Batch 2:  Loss: 1.6208 Validation Accuracy: 43.000001%
# Epoch  8, CIFAR-10 Batch 3:  Loss: 1.5667 Validation Accuracy: 42.680001%
# Epoch  8, CIFAR-10 Batch 4:  Loss: 1.5521 Validation Accuracy: 43.579999%
# Epoch  8, CIFAR-10 Batch 5:  Loss: 1.5971 Validation Accuracy: 43.439999%
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.6069 Validation Accuracy: 43.320000%
# Epoch  9, CIFAR-10 Batch 2:  Loss: 1.6053 Validation Accuracy: 43.779999%
# Epoch  9, CIFAR-10 Batch 3:  Loss: 1.5244 Validation Accuracy: 43.399999%
# Epoch  9, CIFAR-10 Batch 4:  Loss: 1.5282 Validation Accuracy: 43.700001%
# Epoch  9, CIFAR-10 Batch 5:  Loss: 1.5596 Validation Accuracy: 43.300000%
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.6009 Validation Accuracy: 44.600001%
# Epoch 10, CIFAR-10 Batch 2:  Loss: 1.5570 Validation Accuracy: 43.920001%
# Epoch 10, CIFAR-10 Batch 3:  Loss: 1.5021 Validation Accuracy: 44.960001%
# Epoch 10, CIFAR-10 Batch 4:  Loss: 1.4963 Validation Accuracy: 45.320001%
# Epoch 10, CIFAR-10 Batch 5:  Loss: 1.5425 Validation Accuracy: 44.540000%
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.5598 Validation Accuracy: 45.860001%
# Epoch 11, CIFAR-10 Batch 2:  Loss: 1.5475 Validation Accuracy: 45.480001%
# Epoch 11, CIFAR-10 Batch 3:  Loss: 1.4804 Validation Accuracy: 45.860001%
# Epoch 11, CIFAR-10 Batch 4:  Loss: 1.4650 Validation Accuracy: 45.899999%
# Epoch 11, CIFAR-10 Batch 5:  Loss: 1.5206 Validation Accuracy: 45.060000%
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.5262 Validation Accuracy: 46.619999%
# Epoch 12, CIFAR-10 Batch 2:  Loss: 1.5228 Validation Accuracy: 46.340001%
# Epoch 12, CIFAR-10 Batch 3:  Loss: 1.4458 Validation Accuracy: 46.140000%
# Epoch 12, CIFAR-10 Batch 4:  Loss: 1.4379 Validation Accuracy: 47.260001%
# Epoch 12, CIFAR-10 Batch 5:  Loss: 1.4952 Validation Accuracy: 46.320000%
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.5170 Validation Accuracy: 47.160000%
# Epoch 13, CIFAR-10 Batch 2:  Loss: 1.4942 Validation Accuracy: 46.039999%
# Epoch 13, CIFAR-10 Batch 3:  Loss: 1.4285 Validation Accuracy: 46.059999%
# Epoch 13, CIFAR-10 Batch 4:  Loss: 1.4142 Validation Accuracy: 47.620001%
# Epoch 13, CIFAR-10 Batch 5:  Loss: 1.4732 Validation Accuracy: 47.860000%
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.4831 Validation Accuracy: 48.040000%
# Epoch 14, CIFAR-10 Batch 2:  Loss: 1.4690 Validation Accuracy: 47.180000%
# Epoch 14, CIFAR-10 Batch 3:  Loss: 1.4115 Validation Accuracy: 48.140001%
# Epoch 14, CIFAR-10 Batch 4:  Loss: 1.3901 Validation Accuracy: 48.620000%
# Epoch 14, CIFAR-10 Batch 5:  Loss: 1.4565 Validation Accuracy: 48.339999%
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.4710 Validation Accuracy: 48.379999%
# Epoch 15, CIFAR-10 Batch 2:  Loss: 1.4393 Validation Accuracy: 47.380000%
# Epoch 15, CIFAR-10 Batch 3:  Loss: 1.3796 Validation Accuracy: 48.260000%
# Epoch 15, CIFAR-10 Batch 4:  Loss: 1.3693 Validation Accuracy: 49.219999%
# Epoch 15, CIFAR-10 Batch 5:  Loss: 1.4253 Validation Accuracy: 48.620000%
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.4564 Validation Accuracy: 48.679999%
# Epoch 16, CIFAR-10 Batch 2:  Loss: 1.4206 Validation Accuracy: 48.400000%
# Epoch 16, CIFAR-10 Batch 3:  Loss: 1.3670 Validation Accuracy: 49.180001%
# Epoch 16, CIFAR-10 Batch 4:  Loss: 1.3497 Validation Accuracy: 49.540001%
# Epoch 16, CIFAR-10 Batch 5:  Loss: 1.4108 Validation Accuracy: 49.660000%
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.4348 Validation Accuracy: 49.059999%
# Epoch 17, CIFAR-10 Batch 2:  Loss: 1.4036 Validation Accuracy: 48.780000%
# Epoch 17, CIFAR-10 Batch 3:  Loss: 1.3526 Validation Accuracy: 48.640001%
# Epoch 17, CIFAR-10 Batch 4:  Loss: 1.3245 Validation Accuracy: 49.419999%
# Epoch 17, CIFAR-10 Batch 5:  Loss: 1.4001 Validation Accuracy: 49.399999%
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.4165 Validation Accuracy: 49.880001%
# Epoch 18, CIFAR-10 Batch 2:  Loss: 1.3994 Validation Accuracy: 49.000001%
# Epoch 18, CIFAR-10 Batch 3:  Loss: 1.3330 Validation Accuracy: 49.939999%
# Epoch 18, CIFAR-10 Batch 4:  Loss: 1.3070 Validation Accuracy: 49.500000%
# Epoch 18, CIFAR-10 Batch 5:  Loss: 1.3818 Validation Accuracy: 49.779999%
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.4029 Validation Accuracy: 49.739999%
# Epoch 19, CIFAR-10 Batch 2:  Loss: 1.3778 Validation Accuracy: 49.340001%
# Epoch 19, CIFAR-10 Batch 3:  Loss: 1.3156 Validation Accuracy: 50.279999%
# Epoch 19, CIFAR-10 Batch 4:  Loss: 1.3070 Validation Accuracy: 49.759999%
# Epoch 19, CIFAR-10 Batch 5:  Loss: 1.3679 Validation Accuracy: 50.379997%
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.3885 Validation Accuracy: 50.540000%
# Epoch 20, CIFAR-10 Batch 2:  Loss: 1.3680 Validation Accuracy: 49.180001%
# Epoch 20, CIFAR-10 Batch 3:  Loss: 1.3181 Validation Accuracy: 50.459999%
# Epoch 20, CIFAR-10 Batch 4:  Loss: 1.2860 Validation Accuracy: 50.180000%
# Epoch 20, CIFAR-10 Batch 5:  Loss: 1.3484 Validation Accuracy: 50.620002%
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.3680 Validation Accuracy: 50.639999%
# Epoch 21, CIFAR-10 Batch 2:  Loss: 1.3489 Validation Accuracy: 50.160003%
# Epoch 21, CIFAR-10 Batch 3:  Loss: 1.2879 Validation Accuracy: 51.239997%
# Epoch 21, CIFAR-10 Batch 4:  Loss: 1.2770 Validation Accuracy: 50.660002%
# Epoch 21, CIFAR-10 Batch 5:  Loss: 1.3383 Validation Accuracy: 50.860000%
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.3535 Validation Accuracy: 50.900000%
# Epoch 22, CIFAR-10 Batch 2:  Loss: 1.3316 Validation Accuracy: 50.880003%
# Epoch 22, CIFAR-10 Batch 3:  Loss: 1.2869 Validation Accuracy: 50.779998%
# Epoch 22, CIFAR-10 Batch 4:  Loss: 1.2453 Validation Accuracy: 51.539999%
# Epoch 22, CIFAR-10 Batch 5:  Loss: 1.3301 Validation Accuracy: 51.160002%
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.3383 Validation Accuracy: 51.499999%
# Epoch 23, CIFAR-10 Batch 2:  Loss: 1.3255 Validation Accuracy: 50.760001%
# Epoch 23, CIFAR-10 Batch 3:  Loss: 1.2746 Validation Accuracy: 51.260000%
# Epoch 23, CIFAR-10 Batch 4:  Loss: 1.2452 Validation Accuracy: 51.620001%
# Epoch 23, CIFAR-10 Batch 5:  Loss: 1.3009 Validation Accuracy: 51.440001%
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.3358 Validation Accuracy: 51.779997%
# Epoch 24, CIFAR-10 Batch 2:  Loss: 1.3118 Validation Accuracy: 51.700002%
# Epoch 24, CIFAR-10 Batch 3:  Loss: 1.2646 Validation Accuracy: 51.819998%
# Epoch 24, CIFAR-10 Batch 4:  Loss: 1.2337 Validation Accuracy: 51.440001%
# Epoch 24, CIFAR-10 Batch 5:  Loss: 1.3123 Validation Accuracy: 52.179998%
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.3172 Validation Accuracy: 51.740003%
# Epoch 25, CIFAR-10 Batch 2:  Loss: 1.2984 Validation Accuracy: 51.539999%
# Epoch 25, CIFAR-10 Batch 3:  Loss: 1.2567 Validation Accuracy: 51.380002%
# Epoch 25, CIFAR-10 Batch 4:  Loss: 1.2256 Validation Accuracy: 51.819998%
# Epoch 25, CIFAR-10 Batch 5:  Loss: 1.2912 Validation Accuracy: 51.840001%
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.3106 Validation Accuracy: 51.800001%
# Epoch 26, CIFAR-10 Batch 2:  Loss: 1.2960 Validation Accuracy: 50.900000%
# Epoch 26, CIFAR-10 Batch 3:  Loss: 1.2525 Validation Accuracy: 51.899999%
# Epoch 26, CIFAR-10 Batch 4:  Loss: 1.2136 Validation Accuracy: 51.620001%
# Epoch 26, CIFAR-10 Batch 5:  Loss: 1.2825 Validation Accuracy: 51.940000%
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.2970 Validation Accuracy: 52.139997%
# Epoch 27, CIFAR-10 Batch 2:  Loss: 1.2866 Validation Accuracy: 51.380002%
# Epoch 27, CIFAR-10 Batch 3:  Loss: 1.2310 Validation Accuracy: 52.240002%
# Epoch 27, CIFAR-10 Batch 4:  Loss: 1.2016 Validation Accuracy: 52.319998%
# Epoch 27, CIFAR-10 Batch 5:  Loss: 1.2757 Validation Accuracy: 52.480000%
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.2948 Validation Accuracy: 51.840001%
# Epoch 28, CIFAR-10 Batch 2:  Loss: 1.2763 Validation Accuracy: 52.340001%
# Epoch 28, CIFAR-10 Batch 3:  Loss: 1.2233 Validation Accuracy: 52.700001%
# Epoch 28, CIFAR-10 Batch 4:  Loss: 1.1978 Validation Accuracy: 52.600002%
# Epoch 28, CIFAR-10 Batch 5:  Loss: 1.2663 Validation Accuracy: 52.139997%
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.2840 Validation Accuracy: 52.120000%
# Epoch 29, CIFAR-10 Batch 2:  Loss: 1.2757 Validation Accuracy: 52.200001%
# Epoch 29, CIFAR-10 Batch 3:  Loss: 1.2249 Validation Accuracy: 52.660000%
# Epoch 29, CIFAR-10 Batch 4:  Loss: 1.1903 Validation Accuracy: 52.420002%
# Epoch 29, CIFAR-10 Batch 5:  Loss: 1.2522 Validation Accuracy: 52.660000%
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.2723 Validation Accuracy: 52.819997%
# Epoch 30, CIFAR-10 Batch 2:  Loss: 1.2616 Validation Accuracy: 52.380002%
# Epoch 30, CIFAR-10 Batch 3:  Loss: 1.2113 Validation Accuracy: 52.859998%
# Epoch 30, CIFAR-10 Batch 4:  Loss: 1.1754 Validation Accuracy: 52.899998%
# Epoch 30, CIFAR-10 Batch 5:  Loss: 1.2469 Validation Accuracy: 53.140002%
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.2607 Validation Accuracy: 52.460003%
# Epoch 31, CIFAR-10 Batch 2:  Loss: 1.2578 Validation Accuracy: 52.319998%
# Epoch 31, CIFAR-10 Batch 3:  Loss: 1.1949 Validation Accuracy: 53.380001%
# Epoch 31, CIFAR-10 Batch 4:  Loss: 1.1711 Validation Accuracy: 53.100002%
# Epoch 31, CIFAR-10 Batch 5:  Loss: 1.2310 Validation Accuracy: 52.999997%
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.2602 Validation Accuracy: 52.819997%
# Epoch 32, CIFAR-10 Batch 2:  Loss: 1.2500 Validation Accuracy: 52.899998%
# Epoch 32, CIFAR-10 Batch 3:  Loss: 1.1874 Validation Accuracy: 53.079998%
# Epoch 32, CIFAR-10 Batch 4:  Loss: 1.1589 Validation Accuracy: 53.439999%
# Epoch 32, CIFAR-10 Batch 5:  Loss: 1.2258 Validation Accuracy: 52.740002%
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.2470 Validation Accuracy: 53.020000%
# Epoch 33, CIFAR-10 Batch 2:  Loss: 1.2366 Validation Accuracy: 53.100002%
# Epoch 33, CIFAR-10 Batch 3:  Loss: 1.1810 Validation Accuracy: 53.039998%
# Epoch 33, CIFAR-10 Batch 4:  Loss: 1.1556 Validation Accuracy: 53.759998%
# Epoch 33, CIFAR-10 Batch 5:  Loss: 1.2217 Validation Accuracy: 53.240001%
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.2366 Validation Accuracy: 52.800000%
# Epoch 34, CIFAR-10 Batch 2:  Loss: 1.2343 Validation Accuracy: 53.140002%
# Epoch 34, CIFAR-10 Batch 3:  Loss: 1.1810 Validation Accuracy: 53.899997%
# Epoch 34, CIFAR-10 Batch 4:  Loss: 1.1416 Validation Accuracy: 53.719997%
# Epoch 34, CIFAR-10 Batch 5:  Loss: 1.2137 Validation Accuracy: 53.320003%
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.2252 Validation Accuracy: 53.579998%
# Epoch 35, CIFAR-10 Batch 2:  Loss: 1.2280 Validation Accuracy: 53.359997%
# Epoch 35, CIFAR-10 Batch 3:  Loss: 1.1654 Validation Accuracy: 53.820002%
# Epoch 35, CIFAR-10 Batch 4:  Loss: 1.1362 Validation Accuracy: 53.759998%
# Epoch 35, CIFAR-10 Batch 5:  Loss: 1.1990 Validation Accuracy: 53.979999%
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.2208 Validation Accuracy: 53.619999%
# Epoch 36, CIFAR-10 Batch 2:  Loss: 1.2138 Validation Accuracy: 53.240001%
# Epoch 36, CIFAR-10 Batch 3:  Loss: 1.1588 Validation Accuracy: 54.000002%
# Epoch 36, CIFAR-10 Batch 4:  Loss: 1.1379 Validation Accuracy: 53.880000%
# Epoch 36, CIFAR-10 Batch 5:  Loss: 1.1946 Validation Accuracy: 53.920001%
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.2070 Validation Accuracy: 53.619999%
# Epoch 37, CIFAR-10 Batch 2:  Loss: 1.2106 Validation Accuracy: 52.999997%
# Epoch 37, CIFAR-10 Batch 3:  Loss: 1.1489 Validation Accuracy: 54.360002%
# Epoch 37, CIFAR-10 Batch 4:  Loss: 1.1237 Validation Accuracy: 53.820002%
# Epoch 37, CIFAR-10 Batch 5:  Loss: 1.1858 Validation Accuracy: 53.659999%
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.1953 Validation Accuracy: 53.939998%
# Epoch 38, CIFAR-10 Batch 2:  Loss: 1.2023 Validation Accuracy: 53.619999%
# Epoch 38, CIFAR-10 Batch 3:  Loss: 1.1459 Validation Accuracy: 53.920001%
# Epoch 38, CIFAR-10 Batch 4:  Loss: 1.1310 Validation Accuracy: 54.159999%
# Epoch 38, CIFAR-10 Batch 5:  Loss: 1.1665 Validation Accuracy: 53.799999%
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.1844 Validation Accuracy: 54.159999%
# Epoch 39, CIFAR-10 Batch 2:  Loss: 1.1907 Validation Accuracy: 54.060000%
# Epoch 39, CIFAR-10 Batch 3:  Loss: 1.1326 Validation Accuracy: 54.560000%
# Epoch 39, CIFAR-10 Batch 4:  Loss: 1.1081 Validation Accuracy: 54.720002%
# Epoch 39, CIFAR-10 Batch 5:  Loss: 1.1638 Validation Accuracy: 54.060000%
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.1859 Validation Accuracy: 54.200000%
# Epoch 40, CIFAR-10 Batch 2:  Loss: 1.1883 Validation Accuracy: 54.060000%
# Epoch 40, CIFAR-10 Batch 3:  Loss: 1.1273 Validation Accuracy: 54.659998%
# Epoch 40, CIFAR-10 Batch 4:  Loss: 1.0961 Validation Accuracy: 54.519999%
# Epoch 40, CIFAR-10 Batch 5:  Loss: 1.1533 Validation Accuracy: 54.659998%
# Epoch 41, CIFAR-10 Batch 1:  Loss: 1.1708 Validation Accuracy: 54.600000%
# Epoch 41, CIFAR-10 Batch 2:  Loss: 1.1755 Validation Accuracy: 54.119998%
# Epoch 41, CIFAR-10 Batch 3:  Loss: 1.1130 Validation Accuracy: 55.080003%
# Epoch 41, CIFAR-10 Batch 4:  Loss: 1.1031 Validation Accuracy: 54.560000%
# Epoch 41, CIFAR-10 Batch 5:  Loss: 1.1410 Validation Accuracy: 54.699999%
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.1682 Validation Accuracy: 54.619998%
# Epoch 42, CIFAR-10 Batch 2:  Loss: 1.1794 Validation Accuracy: 54.479998%
# Epoch 42, CIFAR-10 Batch 3:  Loss: 1.1085 Validation Accuracy: 55.059999%
# Epoch 42, CIFAR-10 Batch 4:  Loss: 1.1001 Validation Accuracy: 54.159999%
# Epoch 42, CIFAR-10 Batch 5:  Loss: 1.1339 Validation Accuracy: 54.360002%
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.1588 Validation Accuracy: 54.979998%
# Epoch 43, CIFAR-10 Batch 2:  Loss: 1.1658 Validation Accuracy: 54.519999%
# Epoch 43, CIFAR-10 Batch 3:  Loss: 1.0999 Validation Accuracy: 55.199999%
# Epoch 43, CIFAR-10 Batch 4:  Loss: 1.0870 Validation Accuracy: 54.900002%
# Epoch 43, CIFAR-10 Batch 5:  Loss: 1.1292 Validation Accuracy: 55.100000%
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.1556 Validation Accuracy: 54.740000%
# Epoch 44, CIFAR-10 Batch 2:  Loss: 1.1562 Validation Accuracy: 55.059999%
# Epoch 44, CIFAR-10 Batch 3:  Loss: 1.0935 Validation Accuracy: 55.419999%
# Epoch 44, CIFAR-10 Batch 4:  Loss: 1.0804 Validation Accuracy: 54.759997%
# Epoch 44, CIFAR-10 Batch 5:  Loss: 1.1264 Validation Accuracy: 55.440003%
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.1438 Validation Accuracy: 54.900002%
# Epoch 45, CIFAR-10 Batch 2:  Loss: 1.1553 Validation Accuracy: 54.799998%
# Epoch 45, CIFAR-10 Batch 3:  Loss: 1.0892 Validation Accuracy: 54.960001%
# Epoch 45, CIFAR-10 Batch 4:  Loss: 1.0679 Validation Accuracy: 55.220002%
# Epoch 45, CIFAR-10 Batch 5:  Loss: 1.1156 Validation Accuracy: 55.680001%
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.1372 Validation Accuracy: 55.360001%
# Epoch 46, CIFAR-10 Batch 2:  Loss: 1.1510 Validation Accuracy: 54.860002%
# Epoch 46, CIFAR-10 Batch 3:  Loss: 1.0846 Validation Accuracy: 55.239999%
# Epoch 46, CIFAR-10 Batch 4:  Loss: 1.0724 Validation Accuracy: 54.879999%
# Epoch 46, CIFAR-10 Batch 5:  Loss: 1.1181 Validation Accuracy: 55.519998%
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.1267 Validation Accuracy: 55.220002%
# Epoch 47, CIFAR-10 Batch 2:  Loss: 1.1443 Validation Accuracy: 55.080003%
# Epoch 47, CIFAR-10 Batch 3:  Loss: 1.0737 Validation Accuracy: 55.419999%
# Epoch 47, CIFAR-10 Batch 4:  Loss: 1.0583 Validation Accuracy: 54.900002%
# Epoch 47, CIFAR-10 Batch 5:  Loss: 1.0985 Validation Accuracy: 55.220002%
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.1300 Validation Accuracy: 55.419999%
# Epoch 48, CIFAR-10 Batch 2:  Loss: 1.1355 Validation Accuracy: 55.400002%
# Epoch 48, CIFAR-10 Batch 3:  Loss: 1.0664 Validation Accuracy: 55.460000%
# Epoch 48, CIFAR-10 Batch 4:  Loss: 1.0547 Validation Accuracy: 55.339998%
# Epoch 48, CIFAR-10 Batch 5:  Loss: 1.1011 Validation Accuracy: 55.879998%
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.1154 Validation Accuracy: 55.419999%
# Epoch 49, CIFAR-10 Batch 2:  Loss: 1.1271 Validation Accuracy: 55.360001%
# Epoch 49, CIFAR-10 Batch 3:  Loss: 1.0570 Validation Accuracy: 55.479997%
# Epoch 49, CIFAR-10 Batch 4:  Loss: 1.0416 Validation Accuracy: 55.599999%
# Epoch 49, CIFAR-10 Batch 5:  Loss: 1.0923 Validation Accuracy: 56.160003%
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.1116 Validation Accuracy: 55.180001%
# Epoch 50, CIFAR-10 Batch 2:  Loss: 1.1237 Validation Accuracy: 55.659997%
# Epoch 50, CIFAR-10 Batch 3:  Loss: 1.0502 Validation Accuracy: 55.940002%
# Epoch 50, CIFAR-10 Batch 4:  Loss: 1.0311 Validation Accuracy: 55.580002%
# Epoch 50, CIFAR-10 Batch 5:  Loss: 1.0852 Validation Accuracy: 56.080002%
# Epoch 51, CIFAR-10 Batch 1:  Loss: 1.0985 Validation Accuracy: 55.460000%
# Epoch 51, CIFAR-10 Batch 2:  Loss: 1.1085 Validation Accuracy: 55.360001%
# Epoch 51, CIFAR-10 Batch 3:  Loss: 1.0604 Validation Accuracy: 55.540001%
# Epoch 51, CIFAR-10 Batch 4:  Loss: 1.0267 Validation Accuracy: 55.739999%
# Epoch 51, CIFAR-10 Batch 5:  Loss: 1.0790 Validation Accuracy: 56.019998%
# Epoch 52, CIFAR-10 Batch 1:  Loss: 1.0987 Validation Accuracy: 55.599999%
# Epoch 52, CIFAR-10 Batch 2:  Loss: 1.1158 Validation Accuracy: 55.260003%
# Epoch 52, CIFAR-10 Batch 3:  Loss: 1.0447 Validation Accuracy: 56.019998%
# Epoch 52, CIFAR-10 Batch 4:  Loss: 1.0247 Validation Accuracy: 56.120002%
# Epoch 52, CIFAR-10 Batch 5:  Loss: 1.0750 Validation Accuracy: 56.480002%
# Epoch 53, CIFAR-10 Batch 1:  Loss: 1.0926 Validation Accuracy: 55.760002%
# Epoch 53, CIFAR-10 Batch 2:  Loss: 1.1039 Validation Accuracy: 56.220001%
# Epoch 53, CIFAR-10 Batch 3:  Loss: 1.0325 Validation Accuracy: 56.120002%
# Epoch 53, CIFAR-10 Batch 4:  Loss: 1.0178 Validation Accuracy: 56.160003%
# Epoch 53, CIFAR-10 Batch 5:  Loss: 1.0675 Validation Accuracy: 56.239998%
# Epoch 54, CIFAR-10 Batch 1:  Loss: 1.0841 Validation Accuracy: 55.760002%
# Epoch 54, CIFAR-10 Batch 2:  Loss: 1.0925 Validation Accuracy: 56.339997%
# Epoch 54, CIFAR-10 Batch 3:  Loss: 1.0262 Validation Accuracy: 56.180000%
# Epoch 54, CIFAR-10 Batch 4:  Loss: 1.0085 Validation Accuracy: 56.140000%
# Epoch 54, CIFAR-10 Batch 5:  Loss: 1.0560 Validation Accuracy: 56.660002%
# Epoch 55, CIFAR-10 Batch 1:  Loss: 1.0791 Validation Accuracy: 55.599999%
# Epoch 55, CIFAR-10 Batch 2:  Loss: 1.0889 Validation Accuracy: 56.379998%
# Epoch 55, CIFAR-10 Batch 3:  Loss: 1.0272 Validation Accuracy: 56.279999%
# Epoch 55, CIFAR-10 Batch 4:  Loss: 1.0000 Validation Accuracy: 56.519997%
# Epoch 55, CIFAR-10 Batch 5:  Loss: 1.0595 Validation Accuracy: 56.339997%
# Epoch 56, CIFAR-10 Batch 1:  Loss: 1.0708 Validation Accuracy: 56.440002%
# Epoch 56, CIFAR-10 Batch 2:  Loss: 1.0782 Validation Accuracy: 56.320000%
# Epoch 56, CIFAR-10 Batch 3:  Loss: 1.0278 Validation Accuracy: 55.820000%
# Epoch 56, CIFAR-10 Batch 4:  Loss: 0.9908 Validation Accuracy: 56.559998%
# Epoch 56, CIFAR-10 Batch 5:  Loss: 1.0573 Validation Accuracy: 56.580001%
# Epoch 57, CIFAR-10 Batch 1:  Loss: 1.0683 Validation Accuracy: 56.239998%
# Epoch 57, CIFAR-10 Batch 2:  Loss: 1.0738 Validation Accuracy: 56.680000%
# Epoch 57, CIFAR-10 Batch 3:  Loss: 1.0235 Validation Accuracy: 56.220001%
# Epoch 57, CIFAR-10 Batch 4:  Loss: 0.9888 Validation Accuracy: 56.500000%
# Epoch 57, CIFAR-10 Batch 5:  Loss: 1.0529 Validation Accuracy: 56.699997%
# Epoch 58, CIFAR-10 Batch 1:  Loss: 1.0564 Validation Accuracy: 56.239998%
# Epoch 58, CIFAR-10 Batch 2:  Loss: 1.0824 Validation Accuracy: 56.400001%
# Epoch 58, CIFAR-10 Batch 3:  Loss: 1.0129 Validation Accuracy: 56.279999%
# Epoch 58, CIFAR-10 Batch 4:  Loss: 0.9812 Validation Accuracy: 56.440002%
# Epoch 58, CIFAR-10 Batch 5:  Loss: 1.0404 Validation Accuracy: 56.480002%
# Epoch 59, CIFAR-10 Batch 1:  Loss: 1.0468 Validation Accuracy: 56.639999%
# Epoch 59, CIFAR-10 Batch 2:  Loss: 1.0599 Validation Accuracy: 56.620002%
# Epoch 59, CIFAR-10 Batch 3:  Loss: 1.0103 Validation Accuracy: 56.059998%
# Epoch 59, CIFAR-10 Batch 4:  Loss: 0.9806 Validation Accuracy: 56.620002%
# Epoch 59, CIFAR-10 Batch 5:  Loss: 1.0343 Validation Accuracy: 56.919998%
# Epoch 60, CIFAR-10 Batch 1:  Loss: 1.0452 Validation Accuracy: 56.480002%
# Epoch 60, CIFAR-10 Batch 2:  Loss: 1.0591 Validation Accuracy: 56.379998%
# Epoch 60, CIFAR-10 Batch 3:  Loss: 0.9993 Validation Accuracy: 56.300002%
# Epoch 60, CIFAR-10 Batch 4:  Loss: 0.9673 Validation Accuracy: 56.819999%
# Epoch 60, CIFAR-10 Batch 5:  Loss: 1.0293 Validation Accuracy: 56.599998%
# Epoch 61, CIFAR-10 Batch 1:  Loss: 1.0408 Validation Accuracy: 56.519997%
# Epoch 61, CIFAR-10 Batch 2:  Loss: 1.0540 Validation Accuracy: 56.860000%
# Epoch 61, CIFAR-10 Batch 3:  Loss: 0.9945 Validation Accuracy: 56.400001%
# Epoch 61, CIFAR-10 Batch 4:  Loss: 0.9694 Validation Accuracy: 56.699997%
# Epoch 61, CIFAR-10 Batch 5:  Loss: 1.0255 Validation Accuracy: 56.400001%
# Epoch 62, CIFAR-10 Batch 1:  Loss: 1.0404 Validation Accuracy: 56.320000%
# Epoch 62, CIFAR-10 Batch 2:  Loss: 1.0428 Validation Accuracy: 56.919998%
# Epoch 62, CIFAR-10 Batch 3:  Loss: 0.9865 Validation Accuracy: 56.559998%
# Epoch 62, CIFAR-10 Batch 4:  Loss: 0.9652 Validation Accuracy: 56.900001%
# Epoch 62, CIFAR-10 Batch 5:  Loss: 1.0170 Validation Accuracy: 56.699997%
# Epoch 63, CIFAR-10 Batch 1:  Loss: 1.0393 Validation Accuracy: 56.440002%
# Epoch 63, CIFAR-10 Batch 2:  Loss: 1.0332 Validation Accuracy: 56.519997%
# Epoch 63, CIFAR-10 Batch 3:  Loss: 0.9882 Validation Accuracy: 56.760001%
# Epoch 63, CIFAR-10 Batch 4:  Loss: 0.9641 Validation Accuracy: 56.760001%
# Epoch 63, CIFAR-10 Batch 5:  Loss: 1.0211 Validation Accuracy: 56.800002%
# Epoch 64, CIFAR-10 Batch 1:  Loss: 1.0203 Validation Accuracy: 56.840003%
# Epoch 64, CIFAR-10 Batch 2:  Loss: 1.0298 Validation Accuracy: 56.999999%
# Epoch 64, CIFAR-10 Batch 3:  Loss: 0.9775 Validation Accuracy: 56.900001%
# Epoch 64, CIFAR-10 Batch 4:  Loss: 0.9546 Validation Accuracy: 56.819999%
# Epoch 64, CIFAR-10 Batch 5:  Loss: 1.0109 Validation Accuracy: 56.739998%
# Epoch 65, CIFAR-10 Batch 1:  Loss: 1.0140 Validation Accuracy: 56.900001%
# Epoch 65, CIFAR-10 Batch 2:  Loss: 1.0326 Validation Accuracy: 57.220000%
# Epoch 65, CIFAR-10 Batch 3:  Loss: 0.9831 Validation Accuracy: 56.620002%
# Epoch 65, CIFAR-10 Batch 4:  Loss: 0.9511 Validation Accuracy: 57.200003%
# Epoch 65, CIFAR-10 Batch 5:  Loss: 1.0066 Validation Accuracy: 57.260001%
# Epoch 66, CIFAR-10 Batch 1:  Loss: 1.0040 Validation Accuracy: 57.220000%
# Epoch 66, CIFAR-10 Batch 2:  Loss: 1.0242 Validation Accuracy: 57.179999%
# Epoch 66, CIFAR-10 Batch 3:  Loss: 0.9721 Validation Accuracy: 57.080001%
# Epoch 66, CIFAR-10 Batch 4:  Loss: 0.9484 Validation Accuracy: 57.099998%
# Epoch 66, CIFAR-10 Batch 5:  Loss: 0.9978 Validation Accuracy: 57.459998%
# Epoch 67, CIFAR-10 Batch 1:  Loss: 1.0124 Validation Accuracy: 57.040000%
# Epoch 67, CIFAR-10 Batch 2:  Loss: 1.0183 Validation Accuracy: 56.739998%
# Epoch 67, CIFAR-10 Batch 3:  Loss: 0.9621 Validation Accuracy: 57.359999%
# Epoch 67, CIFAR-10 Batch 4:  Loss: 0.9464 Validation Accuracy: 57.179999%
# Epoch 67, CIFAR-10 Batch 5:  Loss: 0.9982 Validation Accuracy: 57.300001%
# Epoch 68, CIFAR-10 Batch 1:  Loss: 0.9995 Validation Accuracy: 56.980002%
# Epoch 68, CIFAR-10 Batch 2:  Loss: 1.0116 Validation Accuracy: 57.419997%
# Epoch 68, CIFAR-10 Batch 3:  Loss: 0.9561 Validation Accuracy: 56.999999%
# Epoch 68, CIFAR-10 Batch 4:  Loss: 0.9417 Validation Accuracy: 57.319999%
# Epoch 68, CIFAR-10 Batch 5:  Loss: 0.9842 Validation Accuracy: 57.400000%
# Epoch 69, CIFAR-10 Batch 1:  Loss: 0.9951 Validation Accuracy: 57.400000%
# Epoch 69, CIFAR-10 Batch 2:  Loss: 1.0124 Validation Accuracy: 57.279998%
# Epoch 69, CIFAR-10 Batch 3:  Loss: 0.9561 Validation Accuracy: 57.160002%
# Epoch 69, CIFAR-10 Batch 4:  Loss: 0.9367 Validation Accuracy: 57.300001%
# Epoch 69, CIFAR-10 Batch 5:  Loss: 0.9807 Validation Accuracy: 57.380003%
# Epoch 70, CIFAR-10 Batch 1:  Loss: 0.9901 Validation Accuracy: 57.179999%
# Epoch 70, CIFAR-10 Batch 2:  Loss: 1.0159 Validation Accuracy: 56.879997%
# Epoch 70, CIFAR-10 Batch 3:  Loss: 0.9472 Validation Accuracy: 57.120001%
# Epoch 70, CIFAR-10 Batch 4:  Loss: 0.9280 Validation Accuracy: 57.120001%
# Epoch 70, CIFAR-10 Batch 5:  Loss: 0.9905 Validation Accuracy: 56.840003%
# Epoch 71, CIFAR-10 Batch 1:  Loss: 0.9821 Validation Accuracy: 57.020003%
# Epoch 71, CIFAR-10 Batch 2:  Loss: 1.0070 Validation Accuracy: 57.040000%
# Epoch 71, CIFAR-10 Batch 3:  Loss: 0.9394 Validation Accuracy: 57.499999%
# Epoch 71, CIFAR-10 Batch 4:  Loss: 0.9235 Validation Accuracy: 57.380003%
# Epoch 71, CIFAR-10 Batch 5:  Loss: 0.9722 Validation Accuracy: 57.459998%
# Epoch 72, CIFAR-10 Batch 1:  Loss: 0.9753 Validation Accuracy: 57.440001%
# Epoch 72, CIFAR-10 Batch 2:  Loss: 1.0078 Validation Accuracy: 56.660002%
# Epoch 72, CIFAR-10 Batch 3:  Loss: 0.9378 Validation Accuracy: 57.700002%
# Epoch 72, CIFAR-10 Batch 4:  Loss: 0.9321 Validation Accuracy: 57.080001%
# Epoch 72, CIFAR-10 Batch 5:  Loss: 0.9691 Validation Accuracy: 57.059997%
# Epoch 73, CIFAR-10 Batch 1:  Loss: 0.9738 Validation Accuracy: 56.959999%
# Epoch 73, CIFAR-10 Batch 2:  Loss: 0.9935 Validation Accuracy: 57.539999%
# Epoch 73, CIFAR-10 Batch 3:  Loss: 0.9343 Validation Accuracy: 57.480001%
# Epoch 73, CIFAR-10 Batch 4:  Loss: 0.9166 Validation Accuracy: 57.139999%
# Epoch 73, CIFAR-10 Batch 5:  Loss: 0.9603 Validation Accuracy: 57.639998%
# Epoch 74, CIFAR-10 Batch 1:  Loss: 0.9719 Validation Accuracy: 57.260001%
# Epoch 74, CIFAR-10 Batch 2:  Loss: 0.9823 Validation Accuracy: 57.020003%
# Epoch 74, CIFAR-10 Batch 3:  Loss: 0.9382 Validation Accuracy: 57.279998%
# Epoch 74, CIFAR-10 Batch 4:  Loss: 0.9115 Validation Accuracy: 57.599998%
# Epoch 74, CIFAR-10 Batch 5:  Loss: 0.9629 Validation Accuracy: 57.499999%
# Epoch 75, CIFAR-10 Batch 1:  Loss: 0.9796 Validation Accuracy: 57.560003%
# Epoch 75, CIFAR-10 Batch 2:  Loss: 0.9760 Validation Accuracy: 57.620001%
# Epoch 75, CIFAR-10 Batch 3:  Loss: 0.9259 Validation Accuracy: 57.840002%
# Epoch 75, CIFAR-10 Batch 4:  Loss: 0.9081 Validation Accuracy: 57.700002%
# Epoch 75, CIFAR-10 Batch 5:  Loss: 0.9575 Validation Accuracy: 57.400000%
# Epoch 76, CIFAR-10 Batch 1:  Loss: 0.9638 Validation Accuracy: 57.400000%
# Epoch 76, CIFAR-10 Batch 2:  Loss: 0.9780 Validation Accuracy: 57.779998%
# Epoch 76, CIFAR-10 Batch 3:  Loss: 0.9269 Validation Accuracy: 57.679999%
# Epoch 76, CIFAR-10 Batch 4:  Loss: 0.9085 Validation Accuracy: 57.359999%
# Epoch 76, CIFAR-10 Batch 5:  Loss: 0.9528 Validation Accuracy: 57.400000%
# Epoch 77, CIFAR-10 Batch 1:  Loss: 0.9636 Validation Accuracy: 57.459998%
# Epoch 77, CIFAR-10 Batch 2:  Loss: 0.9816 Validation Accuracy: 57.480001%
# Epoch 77, CIFAR-10 Batch 3:  Loss: 0.9174 Validation Accuracy: 57.380003%
# Epoch 77, CIFAR-10 Batch 4:  Loss: 0.9037 Validation Accuracy: 57.599998%
# Epoch 77, CIFAR-10 Batch 5:  Loss: 0.9505 Validation Accuracy: 57.700002%
# Epoch 78, CIFAR-10 Batch 1:  Loss: 0.9500 Validation Accuracy: 57.459998%
# Epoch 78, CIFAR-10 Batch 2:  Loss: 0.9734 Validation Accuracy: 57.139999%
# Epoch 78, CIFAR-10 Batch 3:  Loss: 0.9208 Validation Accuracy: 57.740003%
# Epoch 78, CIFAR-10 Batch 4:  Loss: 0.8961 Validation Accuracy: 57.459998%
# Epoch 78, CIFAR-10 Batch 5:  Loss: 0.9428 Validation Accuracy: 57.440001%
# Epoch 79, CIFAR-10 Batch 1:  Loss: 0.9506 Validation Accuracy: 57.139999%
# Epoch 79, CIFAR-10 Batch 2:  Loss: 0.9675 Validation Accuracy: 57.480001%
# Epoch 79, CIFAR-10 Batch 3:  Loss: 0.9105 Validation Accuracy: 57.639998%
# Epoch 79, CIFAR-10 Batch 4:  Loss: 0.8900 Validation Accuracy: 57.539999%
# Epoch 79, CIFAR-10 Batch 5:  Loss: 0.9382 Validation Accuracy: 57.740003%
# Epoch 80, CIFAR-10 Batch 1:  Loss: 0.9396 Validation Accuracy: 57.700002%
# Epoch 80, CIFAR-10 Batch 2:  Loss: 0.9639 Validation Accuracy: 57.380003%
# Epoch 80, CIFAR-10 Batch 3:  Loss: 0.9047 Validation Accuracy: 57.440001%
# Epoch 80, CIFAR-10 Batch 4:  Loss: 0.8908 Validation Accuracy: 57.980001%
# Epoch 80, CIFAR-10 Batch 5:  Loss: 0.9316 Validation Accuracy: 57.620001%
# Epoch 81, CIFAR-10 Batch 1:  Loss: 0.9492 Validation Accuracy: 57.419997%
# Epoch 81, CIFAR-10 Batch 2:  Loss: 0.9569 Validation Accuracy: 57.900000%
# Epoch 81, CIFAR-10 Batch 3:  Loss: 0.8969 Validation Accuracy: 57.560003%
# Epoch 81, CIFAR-10 Batch 4:  Loss: 0.8849 Validation Accuracy: 57.440001%
# Epoch 81, CIFAR-10 Batch 5:  Loss: 0.9319 Validation Accuracy: 57.660002%
# Epoch 82, CIFAR-10 Batch 1:  Loss: 0.9380 Validation Accuracy: 57.700002%
# Epoch 82, CIFAR-10 Batch 2:  Loss: 0.9564 Validation Accuracy: 57.279998%
# Epoch 82, CIFAR-10 Batch 3:  Loss: 0.8962 Validation Accuracy: 57.520002%
# Epoch 82, CIFAR-10 Batch 4:  Loss: 0.8784 Validation Accuracy: 57.740003%
# Epoch 82, CIFAR-10 Batch 5:  Loss: 0.9211 Validation Accuracy: 57.599998%
# Epoch 83, CIFAR-10 Batch 1:  Loss: 0.9324 Validation Accuracy: 57.380003%
# Epoch 83, CIFAR-10 Batch 2:  Loss: 0.9486 Validation Accuracy: 57.499999%
# Epoch 83, CIFAR-10 Batch 3:  Loss: 0.8991 Validation Accuracy: 57.639998%
# Epoch 83, CIFAR-10 Batch 4:  Loss: 0.8828 Validation Accuracy: 57.200003%
# Epoch 83, CIFAR-10 Batch 5:  Loss: 0.9154 Validation Accuracy: 57.940000%
# Epoch 84, CIFAR-10 Batch 1:  Loss: 0.9380 Validation Accuracy: 57.419997%
# Epoch 84, CIFAR-10 Batch 2:  Loss: 0.9482 Validation Accuracy: 56.999999%
# Epoch 84, CIFAR-10 Batch 3:  Loss: 0.8942 Validation Accuracy: 57.539999%
# Epoch 84, CIFAR-10 Batch 4:  Loss: 0.8814 Validation Accuracy: 57.359999%
# Epoch 84, CIFAR-10 Batch 5:  Loss: 0.9183 Validation Accuracy: 57.720000%
# Epoch 85, CIFAR-10 Batch 1:  Loss: 0.9289 Validation Accuracy: 57.639998%
# Epoch 85, CIFAR-10 Batch 2:  Loss: 0.9356 Validation Accuracy: 57.700002%
# Epoch 85, CIFAR-10 Batch 3:  Loss: 0.8809 Validation Accuracy: 57.900000%
# Epoch 85, CIFAR-10 Batch 4:  Loss: 0.8678 Validation Accuracy: 57.620001%
# Epoch 85, CIFAR-10 Batch 5:  Loss: 0.9118 Validation Accuracy: 57.959998%
# Epoch 86, CIFAR-10 Batch 1:  Loss: 0.9198 Validation Accuracy: 57.999998%
# Epoch 86, CIFAR-10 Batch 2:  Loss: 0.9311 Validation Accuracy: 57.480001%
# Epoch 86, CIFAR-10 Batch 3:  Loss: 0.8806 Validation Accuracy: 57.700002%
# Epoch 86, CIFAR-10 Batch 4:  Loss: 0.8743 Validation Accuracy: 57.620001%
# Epoch 86, CIFAR-10 Batch 5:  Loss: 0.9007 Validation Accuracy: 57.779998%
# Epoch 87, CIFAR-10 Batch 1:  Loss: 0.9118 Validation Accuracy: 57.499999%
# Epoch 87, CIFAR-10 Batch 2:  Loss: 0.9401 Validation Accuracy: 57.660002%
# Epoch 87, CIFAR-10 Batch 3:  Loss: 0.8775 Validation Accuracy: 57.779998%
# Epoch 87, CIFAR-10 Batch 4:  Loss: 0.8670 Validation Accuracy: 58.080000%
# Epoch 87, CIFAR-10 Batch 5:  Loss: 0.9058 Validation Accuracy: 57.599998%
# Epoch 88, CIFAR-10 Batch 1:  Loss: 0.9104 Validation Accuracy: 58.080000%
# Epoch 88, CIFAR-10 Batch 2:  Loss: 0.9275 Validation Accuracy: 57.840002%
# Epoch 88, CIFAR-10 Batch 3:  Loss: 0.8688 Validation Accuracy: 58.359998%
# Epoch 88, CIFAR-10 Batch 4:  Loss: 0.8650 Validation Accuracy: 58.099997%
# Epoch 88, CIFAR-10 Batch 5:  Loss: 0.8950 Validation Accuracy: 58.080000%
# Epoch 89, CIFAR-10 Batch 1:  Loss: 0.9075 Validation Accuracy: 57.779998%
# Epoch 89, CIFAR-10 Batch 2:  Loss: 0.9259 Validation Accuracy: 57.760000%
# Epoch 89, CIFAR-10 Batch 3:  Loss: 0.8666 Validation Accuracy: 58.139998%
# Epoch 89, CIFAR-10 Batch 4:  Loss: 0.8590 Validation Accuracy: 57.740003%
# Epoch 89, CIFAR-10 Batch 5:  Loss: 0.8854 Validation Accuracy: 57.740003%
# Epoch 90, CIFAR-10 Batch 1:  Loss: 0.9102 Validation Accuracy: 57.679999%
# Epoch 90, CIFAR-10 Batch 2:  Loss: 0.9289 Validation Accuracy: 57.760000%
# Epoch 90, CIFAR-10 Batch 3:  Loss: 0.8667 Validation Accuracy: 57.980001%
# Epoch 90, CIFAR-10 Batch 4:  Loss: 0.8516 Validation Accuracy: 58.060002%
# Epoch 90, CIFAR-10 Batch 5:  Loss: 0.8872 Validation Accuracy: 57.959998%
# Epoch 91, CIFAR-10 Batch 1:  Loss: 0.9036 Validation Accuracy: 57.440001%
# Epoch 91, CIFAR-10 Batch 2:  Loss: 0.9194 Validation Accuracy: 58.279997%
# Epoch 91, CIFAR-10 Batch 3:  Loss: 0.8583 Validation Accuracy: 58.080000%
# Epoch 91, CIFAR-10 Batch 4:  Loss: 0.8591 Validation Accuracy: 57.620001%
# Epoch 91, CIFAR-10 Batch 5:  Loss: 0.8827 Validation Accuracy: 58.120000%
# Epoch 92, CIFAR-10 Batch 1:  Loss: 0.8954 Validation Accuracy: 57.800001%
# Epoch 92, CIFAR-10 Batch 2:  Loss: 0.9193 Validation Accuracy: 58.080000%
# Epoch 92, CIFAR-10 Batch 3:  Loss: 0.8479 Validation Accuracy: 58.359998%
# Epoch 92, CIFAR-10 Batch 4:  Loss: 0.8559 Validation Accuracy: 58.039999%
# Epoch 92, CIFAR-10 Batch 5:  Loss: 0.8828 Validation Accuracy: 58.200002%
# Epoch 93, CIFAR-10 Batch 1:  Loss: 0.8872 Validation Accuracy: 57.920003%
# Epoch 93, CIFAR-10 Batch 2:  Loss: 0.9095 Validation Accuracy: 57.800001%
# Epoch 93, CIFAR-10 Batch 3:  Loss: 0.8628 Validation Accuracy: 58.179998%
# Epoch 93, CIFAR-10 Batch 4:  Loss: 0.8538 Validation Accuracy: 57.819998%
# Epoch 93, CIFAR-10 Batch 5:  Loss: 0.8740 Validation Accuracy: 57.940000%
# Epoch 94, CIFAR-10 Batch 1:  Loss: 0.8827 Validation Accuracy: 57.819998%
# Epoch 94, CIFAR-10 Batch 2:  Loss: 0.9168 Validation Accuracy: 57.980001%
# Epoch 94, CIFAR-10 Batch 3:  Loss: 0.8535 Validation Accuracy: 58.380002%
# Epoch 94, CIFAR-10 Batch 4:  Loss: 0.8338 Validation Accuracy: 57.560003%
# Epoch 94, CIFAR-10 Batch 5:  Loss: 0.8824 Validation Accuracy: 57.900000%
# Epoch 95, CIFAR-10 Batch 1:  Loss: 0.8858 Validation Accuracy: 57.840002%
# Epoch 95, CIFAR-10 Batch 2:  Loss: 0.9079 Validation Accuracy: 58.200002%
# Epoch 95, CIFAR-10 Batch 3:  Loss: 0.8562 Validation Accuracy: 58.240002%
# Epoch 95, CIFAR-10 Batch 4:  Loss: 0.8371 Validation Accuracy: 57.880002%
# Epoch 95, CIFAR-10 Batch 5:  Loss: 0.8693 Validation Accuracy: 58.099997%
# Epoch 96, CIFAR-10 Batch 1:  Loss: 0.8751 Validation Accuracy: 57.580000%
# Epoch 96, CIFAR-10 Batch 2:  Loss: 0.9100 Validation Accuracy: 58.340001%
# Epoch 96, CIFAR-10 Batch 3:  Loss: 0.8394 Validation Accuracy: 58.359998%
# Epoch 96, CIFAR-10 Batch 4:  Loss: 0.8304 Validation Accuracy: 57.840002%
# Epoch 96, CIFAR-10 Batch 5:  Loss: 0.8747 Validation Accuracy: 58.060002%
# Epoch 97, CIFAR-10 Batch 1:  Loss: 0.8745 Validation Accuracy: 57.999998%
# Epoch 97, CIFAR-10 Batch 2:  Loss: 0.9185 Validation Accuracy: 57.800001%
# Epoch 97, CIFAR-10 Batch 3:  Loss: 0.8360 Validation Accuracy: 58.380002%
# Epoch 97, CIFAR-10 Batch 4:  Loss: 0.8331 Validation Accuracy: 58.020002%
# Epoch 97, CIFAR-10 Batch 5:  Loss: 0.8692 Validation Accuracy: 57.819998%
# Epoch 98, CIFAR-10 Batch 1:  Loss: 0.8750 Validation Accuracy: 57.880002%
# Epoch 98, CIFAR-10 Batch 2:  Loss: 0.8907 Validation Accuracy: 58.200002%
# Epoch 98, CIFAR-10 Batch 3:  Loss: 0.8397 Validation Accuracy: 58.120000%
# Epoch 98, CIFAR-10 Batch 4:  Loss: 0.8227 Validation Accuracy: 57.920003%
# Epoch 98, CIFAR-10 Batch 5:  Loss: 0.8689 Validation Accuracy: 58.279997%
# Epoch 99, CIFAR-10 Batch 1:  Loss: 0.8655 Validation Accuracy: 58.260000%
# Epoch 99, CIFAR-10 Batch 2:  Loss: 0.8971 Validation Accuracy: 57.980001%
# Epoch 99, CIFAR-10 Batch 3:  Loss: 0.8274 Validation Accuracy: 58.300000%
# Epoch 99, CIFAR-10 Batch 4:  Loss: 0.8292 Validation Accuracy: 58.099997%
# Epoch 99, CIFAR-10 Batch 5:  Loss: 0.8616 Validation Accuracy: 58.319998%
# Epoch 100, CIFAR-10 Batch 1:  Loss: 0.8727 Validation Accuracy: 58.160001%
# Epoch 100, CIFAR-10 Batch 2:  Loss: 0.8975 Validation Accuracy: 58.300000%
# Epoch 100, CIFAR-10 Batch 3:  Loss: 0.8271 Validation Accuracy: 58.279997%
# Epoch 100, CIFAR-10 Batch 4:  Loss: 0.8249 Validation Accuracy: 58.219999%
# Epoch 100, CIFAR-10 Batch 5:  Loss: 0.8576 Validation Accuracy: 58.380002%
# Epoch 101, CIFAR-10 Batch 1:  Loss: 0.8599 Validation Accuracy: 58.300000%
# Epoch 101, CIFAR-10 Batch 2:  Loss: 0.8958 Validation Accuracy: 58.219999%
# Epoch 101, CIFAR-10 Batch 3:  Loss: 0.8293 Validation Accuracy: 57.980001%
# Epoch 101, CIFAR-10 Batch 4:  Loss: 0.8242 Validation Accuracy: 58.039999%
# Epoch 101, CIFAR-10 Batch 5:  Loss: 0.8568 Validation Accuracy: 57.959998%
# Epoch 102, CIFAR-10 Batch 1:  Loss: 0.8596 Validation Accuracy: 57.539999%
# Epoch 102, CIFAR-10 Batch 2:  Loss: 0.8852 Validation Accuracy: 57.639998%
# Epoch 102, CIFAR-10 Batch 3:  Loss: 0.8335 Validation Accuracy: 57.980001%
# Epoch 102, CIFAR-10 Batch 4:  Loss: 0.8161 Validation Accuracy: 57.679999%
# Epoch 102, CIFAR-10 Batch 5:  Loss: 0.8493 Validation Accuracy: 57.880002%
# Epoch 103, CIFAR-10 Batch 1:  Loss: 0.8481 Validation Accuracy: 58.039999%
# Epoch 103, CIFAR-10 Batch 2:  Loss: 0.8906 Validation Accuracy: 58.319998%
# Epoch 103, CIFAR-10 Batch 3:  Loss: 0.8211 Validation Accuracy: 58.139998%
# Epoch 103, CIFAR-10 Batch 4:  Loss: 0.8162 Validation Accuracy: 57.760000%
# Epoch 103, CIFAR-10 Batch 5:  Loss: 0.8686 Validation Accuracy: 57.940000%
# Epoch 104, CIFAR-10 Batch 1:  Loss: 0.8494 Validation Accuracy: 58.120000%
# Epoch 104, CIFAR-10 Batch 2:  Loss: 0.8862 Validation Accuracy: 58.020002%
# Epoch 104, CIFAR-10 Batch 3:  Loss: 0.8239 Validation Accuracy: 58.099997%
# Epoch 104, CIFAR-10 Batch 4:  Loss: 0.8101 Validation Accuracy: 57.900000%
# Epoch 104, CIFAR-10 Batch 5:  Loss: 0.8502 Validation Accuracy: 57.840002%
# Epoch 105, CIFAR-10 Batch 1:  Loss: 0.8431 Validation Accuracy: 58.080000%
# Epoch 105, CIFAR-10 Batch 2:  Loss: 0.8889 Validation Accuracy: 57.760000%
# Epoch 105, CIFAR-10 Batch 3:  Loss: 0.8158 Validation Accuracy: 58.440000%
# Epoch 105, CIFAR-10 Batch 4:  Loss: 0.8027 Validation Accuracy: 57.900000%
# Epoch 105, CIFAR-10 Batch 5:  Loss: 0.8420 Validation Accuracy: 57.900000%
# Epoch 106, CIFAR-10 Batch 1:  Loss: 0.8490 Validation Accuracy: 58.319998%
# Epoch 106, CIFAR-10 Batch 2:  Loss: 0.8632 Validation Accuracy: 58.179998%
# Epoch 106, CIFAR-10 Batch 3:  Loss: 0.8202 Validation Accuracy: 58.179998%
# Epoch 106, CIFAR-10 Batch 4:  Loss: 0.8037 Validation Accuracy: 57.920003%
# Epoch 106, CIFAR-10 Batch 5:  Loss: 0.8402 Validation Accuracy: 57.800001%
# Epoch 107, CIFAR-10 Batch 1:  Loss: 0.8498 Validation Accuracy: 57.940000%
# Epoch 107, CIFAR-10 Batch 2:  Loss: 0.8710 Validation Accuracy: 58.099997%
# Epoch 107, CIFAR-10 Batch 3:  Loss: 0.8234 Validation Accuracy: 58.080000%
# Epoch 107, CIFAR-10 Batch 4:  Loss: 0.8094 Validation Accuracy: 57.520002%
# Epoch 107, CIFAR-10 Batch 5:  Loss: 0.8327 Validation Accuracy: 57.840002%
# Epoch 108, CIFAR-10 Batch 1:  Loss: 0.8402 Validation Accuracy: 58.200002%
# Epoch 108, CIFAR-10 Batch 2:  Loss: 0.8640 Validation Accuracy: 57.980001%
# Epoch 108, CIFAR-10 Batch 3:  Loss: 0.8156 Validation Accuracy: 58.319998%
# Epoch 108, CIFAR-10 Batch 4:  Loss: 0.8038 Validation Accuracy: 57.800001%
# Epoch 108, CIFAR-10 Batch 5:  Loss: 0.8323 Validation Accuracy: 57.980001%
# Epoch 109, CIFAR-10 Batch 1:  Loss: 0.8376 Validation Accuracy: 57.940000%
# Epoch 109, CIFAR-10 Batch 2:  Loss: 0.8699 Validation Accuracy: 58.080000%
# Epoch 109, CIFAR-10 Batch 3:  Loss: 0.8031 Validation Accuracy: 58.499998%
# Epoch 109, CIFAR-10 Batch 4:  Loss: 0.8012 Validation Accuracy: 58.300000%
# Epoch 109, CIFAR-10 Batch 5:  Loss: 0.8337 Validation Accuracy: 57.920003%
# Epoch 110, CIFAR-10 Batch 1:  Loss: 0.8367 Validation Accuracy: 57.859999%
# Epoch 110, CIFAR-10 Batch 2:  Loss: 0.8607 Validation Accuracy: 57.999998%
# Epoch 110, CIFAR-10 Batch 3:  Loss: 0.8116 Validation Accuracy: 58.300000%
# Epoch 110, CIFAR-10 Batch 4:  Loss: 0.8004 Validation Accuracy: 57.840002%
# Epoch 110, CIFAR-10 Batch 5:  Loss: 0.8239 Validation Accuracy: 58.060002%
# Epoch 111, CIFAR-10 Batch 1:  Loss: 0.8296 Validation Accuracy: 57.959998%
# Epoch 111, CIFAR-10 Batch 2:  Loss: 0.8628 Validation Accuracy: 58.139998%
# Epoch 111, CIFAR-10 Batch 3:  Loss: 0.8046 Validation Accuracy: 58.279997%
# Epoch 111, CIFAR-10 Batch 4:  Loss: 0.7920 Validation Accuracy: 57.859999%
# Epoch 111, CIFAR-10 Batch 5:  Loss: 0.8270 Validation Accuracy: 58.279997%
# Epoch 112, CIFAR-10 Batch 1:  Loss: 0.8262 Validation Accuracy: 58.099997%
# Epoch 112, CIFAR-10 Batch 2:  Loss: 0.8655 Validation Accuracy: 58.120000%
# Epoch 112, CIFAR-10 Batch 3:  Loss: 0.8093 Validation Accuracy: 57.920003%
# Epoch 112, CIFAR-10 Batch 4:  Loss: 0.7890 Validation Accuracy: 58.240002%
# Epoch 112, CIFAR-10 Batch 5:  Loss: 0.8143 Validation Accuracy: 58.179998%
# Epoch 113, CIFAR-10 Batch 1:  Loss: 0.8334 Validation Accuracy: 57.959998%
# Epoch 113, CIFAR-10 Batch 2:  Loss: 0.8543 Validation Accuracy: 57.920003%
# Epoch 113, CIFAR-10 Batch 3:  Loss: 0.8030 Validation Accuracy: 58.440000%
# Epoch 113, CIFAR-10 Batch 4:  Loss: 0.7869 Validation Accuracy: 57.660002%
# Epoch 113, CIFAR-10 Batch 5:  Loss: 0.8188 Validation Accuracy: 58.200002%
# Epoch 114, CIFAR-10 Batch 1:  Loss: 0.8206 Validation Accuracy: 58.060002%
# Epoch 114, CIFAR-10 Batch 2:  Loss: 0.8578 Validation Accuracy: 58.200002%
# Epoch 114, CIFAR-10 Batch 3:  Loss: 0.7899 Validation Accuracy: 58.480000%
# Epoch 114, CIFAR-10 Batch 4:  Loss: 0.7896 Validation Accuracy: 57.660002%
# Epoch 114, CIFAR-10 Batch 5:  Loss: 0.8138 Validation Accuracy: 58.240002%
# Epoch 115, CIFAR-10 Batch 1:  Loss: 0.8191 Validation Accuracy: 58.319998%
# Epoch 115, CIFAR-10 Batch 2:  Loss: 0.8479 Validation Accuracy: 58.219999%
# Epoch 115, CIFAR-10 Batch 3:  Loss: 0.7969 Validation Accuracy: 57.940000%
# Epoch 115, CIFAR-10 Batch 4:  Loss: 0.7874 Validation Accuracy: 57.800001%
# Epoch 115, CIFAR-10 Batch 5:  Loss: 0.8037 Validation Accuracy: 58.459997%
# Epoch 116, CIFAR-10 Batch 1:  Loss: 0.8267 Validation Accuracy: 58.080000%
# Epoch 116, CIFAR-10 Batch 2:  Loss: 0.8435 Validation Accuracy: 58.219999%
# Epoch 116, CIFAR-10 Batch 3:  Loss: 0.8005 Validation Accuracy: 58.279997%
# Epoch 116, CIFAR-10 Batch 4:  Loss: 0.7723 Validation Accuracy: 57.980001%
# Epoch 116, CIFAR-10 Batch 5:  Loss: 0.8075 Validation Accuracy: 58.300000%
# Epoch 117, CIFAR-10 Batch 1:  Loss: 0.8133 Validation Accuracy: 58.039999%
# Epoch 117, CIFAR-10 Batch 2:  Loss: 0.8389 Validation Accuracy: 58.120000%
# Epoch 117, CIFAR-10 Batch 3:  Loss: 0.7833 Validation Accuracy: 58.579999%
# Epoch 117, CIFAR-10 Batch 4:  Loss: 0.7769 Validation Accuracy: 57.980001%
# Epoch 117, CIFAR-10 Batch 5:  Loss: 0.8055 Validation Accuracy: 58.380002%
# Epoch 118, CIFAR-10 Batch 1:  Loss: 0.8125 Validation Accuracy: 57.880002%
# Epoch 118, CIFAR-10 Batch 2:  Loss: 0.8422 Validation Accuracy: 58.420002%
# Epoch 118, CIFAR-10 Batch 3:  Loss: 0.7768 Validation Accuracy: 58.579999%
# Epoch 118, CIFAR-10 Batch 4:  Loss: 0.7810 Validation Accuracy: 58.300000%
# Epoch 118, CIFAR-10 Batch 5:  Loss: 0.8072 Validation Accuracy: 57.999998%
# Epoch 119, CIFAR-10 Batch 1:  Loss: 0.8057 Validation Accuracy: 58.260000%
# Epoch 119, CIFAR-10 Batch 2:  Loss: 0.8485 Validation Accuracy: 57.880002%
# Epoch 119, CIFAR-10 Batch 3:  Loss: 0.7803 Validation Accuracy: 58.219999%
# Epoch 119, CIFAR-10 Batch 4:  Loss: 0.7728 Validation Accuracy: 57.800001%
# Epoch 119, CIFAR-10 Batch 5:  Loss: 0.7948 Validation Accuracy: 58.099997%
# Epoch 120, CIFAR-10 Batch 1:  Loss: 0.8240 Validation Accuracy: 58.020002%
# Epoch 120, CIFAR-10 Batch 2:  Loss: 0.8309 Validation Accuracy: 57.980001%
# Epoch 120, CIFAR-10 Batch 3:  Loss: 0.7834 Validation Accuracy: 58.200002%
# Epoch 120, CIFAR-10 Batch 4:  Loss: 0.7675 Validation Accuracy: 57.999998%
# Epoch 120, CIFAR-10 Batch 5:  Loss: 0.8016 Validation Accuracy: 57.660002%
# Epoch 121, CIFAR-10 Batch 1:  Loss: 0.8142 Validation Accuracy: 58.099997%
# Epoch 121, CIFAR-10 Batch 2:  Loss: 0.8349 Validation Accuracy: 57.999998%
# Epoch 121, CIFAR-10 Batch 3:  Loss: 0.7719 Validation Accuracy: 58.420002%
# Epoch 121, CIFAR-10 Batch 4:  Loss: 0.7748 Validation Accuracy: 58.160001%
# Epoch 121, CIFAR-10 Batch 5:  Loss: 0.7982 Validation Accuracy: 58.039999%
# Epoch 122, CIFAR-10 Batch 1:  Loss: 0.8084 Validation Accuracy: 57.800001%
# Epoch 122, CIFAR-10 Batch 2:  Loss: 0.8291 Validation Accuracy: 58.300000%
# Epoch 122, CIFAR-10 Batch 3:  Loss: 0.7799 Validation Accuracy: 58.039999%
# Epoch 122, CIFAR-10 Batch 4:  Loss: 0.7659 Validation Accuracy: 57.920003%
# Epoch 122, CIFAR-10 Batch 5:  Loss: 0.7885 Validation Accuracy: 58.319998%
# Epoch 123, CIFAR-10 Batch 1:  Loss: 0.8069 Validation Accuracy: 57.940000%
# Epoch 123, CIFAR-10 Batch 2:  Loss: 0.8226 Validation Accuracy: 58.300000%
# Epoch 123, CIFAR-10 Batch 3:  Loss: 0.7688 Validation Accuracy: 58.459997%
# Epoch 123, CIFAR-10 Batch 4:  Loss: 0.7663 Validation Accuracy: 57.639998%
# Epoch 123, CIFAR-10 Batch 5:  Loss: 0.7925 Validation Accuracy: 58.139998%
# Epoch 124, CIFAR-10 Batch 1:  Loss: 0.8018 Validation Accuracy: 58.060002%
# Epoch 124, CIFAR-10 Batch 2:  Loss: 0.8292 Validation Accuracy: 57.279998%
# Epoch 124, CIFAR-10 Batch 3:  Loss: 0.7698 Validation Accuracy: 58.420002%
# Epoch 124, CIFAR-10 Batch 4:  Loss: 0.7634 Validation Accuracy: 57.959998%
# Epoch 124, CIFAR-10 Batch 5:  Loss: 0.7868 Validation Accuracy: 58.319998%
# Epoch 125, CIFAR-10 Batch 1:  Loss: 0.8036 Validation Accuracy: 58.160001%
# Epoch 125, CIFAR-10 Batch 2:  Loss: 0.8172 Validation Accuracy: 58.260000%
# Epoch 125, CIFAR-10 Batch 3:  Loss: 0.7729 Validation Accuracy: 57.959998%
# Epoch 125, CIFAR-10 Batch 4:  Loss: 0.7522 Validation Accuracy: 58.219999%
# Epoch 125, CIFAR-10 Batch 5:  Loss: 0.7934 Validation Accuracy: 57.980001%
# Epoch 126, CIFAR-10 Batch 1:  Loss: 0.7904 Validation Accuracy: 58.179998%
# Epoch 126, CIFAR-10 Batch 2:  Loss: 0.8215 Validation Accuracy: 58.240002%
# Epoch 126, CIFAR-10 Batch 3:  Loss: 0.7605 Validation Accuracy: 58.020002%
# Epoch 126, CIFAR-10 Batch 4:  Loss: 0.7578 Validation Accuracy: 57.859999%
# Epoch 126, CIFAR-10 Batch 5:  Loss: 0.7915 Validation Accuracy: 58.279997%
# Epoch 127, CIFAR-10 Batch 1:  Loss: 0.7942 Validation Accuracy: 58.120000%
# Epoch 127, CIFAR-10 Batch 2:  Loss: 0.8288 Validation Accuracy: 58.499998%
# Epoch 127, CIFAR-10 Batch 3:  Loss: 0.7588 Validation Accuracy: 58.399999%
# Epoch 127, CIFAR-10 Batch 4:  Loss: 0.7655 Validation Accuracy: 57.840002%
# Epoch 127, CIFAR-10 Batch 5:  Loss: 0.7806 Validation Accuracy: 58.319998%
# Epoch 128, CIFAR-10 Batch 1:  Loss: 0.7966 Validation Accuracy: 58.319998%
# Epoch 128, CIFAR-10 Batch 2:  Loss: 0.8323 Validation Accuracy: 58.359998%
# Epoch 128, CIFAR-10 Batch 3:  Loss: 0.7566 Validation Accuracy: 58.260000%
# Epoch 128, CIFAR-10 Batch 4:  Loss: 0.7521 Validation Accuracy: 57.779998%
# Epoch 128, CIFAR-10 Batch 5:  Loss: 0.7789 Validation Accuracy: 58.060002%
# Epoch 129, CIFAR-10 Batch 1:  Loss: 0.7887 Validation Accuracy: 58.099997%
# Epoch 129, CIFAR-10 Batch 2:  Loss: 0.8179 Validation Accuracy: 58.099997%
# Epoch 129, CIFAR-10 Batch 3:  Loss: 0.7577 Validation Accuracy: 58.200002%
# Epoch 129, CIFAR-10 Batch 4:  Loss: 0.7531 Validation Accuracy: 57.740003%
# Epoch 129, CIFAR-10 Batch 5:  Loss: 0.7730 Validation Accuracy: 57.959998%
# Epoch 130, CIFAR-10 Batch 1:  Loss: 0.7922 Validation Accuracy: 57.660002%
# ...
# Epoch 158, CIFAR-10 Batch 3:  Loss: 0.7035 Validation Accuracy: 58.260000%
# Epoch 158, CIFAR-10 Batch 4:  Loss: 0.6893 Validation Accuracy: 58.319998%
# Epoch 158, CIFAR-10 Batch 5:  Loss: 0.7320 Validation Accuracy: 58.319998%
# Epoch 159, CIFAR-10 Batch 1:  Loss: 0.7243 Validation Accuracy: 57.940000%
# Epoch 159, CIFAR-10 Batch 2:  Loss: 0.7696 Validation Accuracy: 58.279997%
# Epoch 159, CIFAR-10 Batch 3:  Loss: 0.6882 Validation Accuracy: 58.300000%
# Epoch 159, CIFAR-10 Batch 4:  Loss: 0.6901 Validation Accuracy: 58.300000%
# Epoch 159, CIFAR-10 Batch 5:  Loss: 0.7158 Validation Accuracy: 58.139998%
# Epoch 160, CIFAR-10 Batch 1:  Loss: 0.7261 Validation Accuracy: 57.900000%
# Epoch 160, CIFAR-10 Batch 2:  Loss: 0.7546 Validation Accuracy: 58.639997%
# Epoch 160, CIFAR-10 Batch 3:  Loss: 0.7008 Validation Accuracy: 58.179998%
# Epoch 160, CIFAR-10 Batch 4:  Loss: 0.6889 Validation Accuracy: 57.760000%
# Epoch 160, CIFAR-10 Batch 5:  Loss: 0.7187 Validation Accuracy: 58.099997%
# Epoch 161, CIFAR-10 Batch 1:  Loss: 0.7200 Validation Accuracy: 58.819997%
# Epoch 161, CIFAR-10 Batch 2:  Loss: 0.7542 Validation Accuracy: 57.920003%
# Epoch 161, CIFAR-10 Batch 3:  Loss: 0.6984 Validation Accuracy: 58.099997%
# Epoch 161, CIFAR-10 Batch 4:  Loss: 0.6904 Validation Accuracy: 57.840002%
# Epoch 161, CIFAR-10 Batch 5:  Loss: 0.7270 Validation Accuracy: 58.120000%
# Epoch 162, CIFAR-10 Batch 1:  Loss: 0.7182 Validation Accuracy: 58.240002%
# Epoch 162, CIFAR-10 Batch 2:  Loss: 0.7516 Validation Accuracy: 58.819997%
# Epoch 162, CIFAR-10 Batch 3:  Loss: 0.6833 Validation Accuracy: 58.660001%
# Epoch 162, CIFAR-10 Batch 4:  Loss: 0.6905 Validation Accuracy: 58.719999%
# Epoch 162, CIFAR-10 Batch 5:  Loss: 0.7211 Validation Accuracy: 58.099997%
# Epoch 163, CIFAR-10 Batch 1:  Loss: 0.7174 Validation Accuracy: 57.819998%
# Epoch 163, CIFAR-10 Batch 2:  Loss: 0.7571 Validation Accuracy: 58.380002%
# Epoch 163, CIFAR-10 Batch 3:  Loss: 0.6869 Validation Accuracy: 58.480000%
# Epoch 163, CIFAR-10 Batch 4:  Loss: 0.6819 Validation Accuracy: 58.560002%
# Epoch 163, CIFAR-10 Batch 5:  Loss: 0.7178 Validation Accuracy: 58.179998%
# Epoch 164, CIFAR-10 Batch 1:  Loss: 0.7277 Validation Accuracy: 58.179998%
# Epoch 164, CIFAR-10 Batch 2:  Loss: 0.7459 Validation Accuracy: 58.539999%
# Epoch 164, CIFAR-10 Batch 3:  Loss: 0.6868 Validation Accuracy: 58.560002%
# Epoch 164, CIFAR-10 Batch 4:  Loss: 0.6901 Validation Accuracy: 58.499998%
# Epoch 164, CIFAR-10 Batch 5:  Loss: 0.7141 Validation Accuracy: 58.099997%
# Epoch 165, CIFAR-10 Batch 1:  Loss: 0.7210 Validation Accuracy: 58.499998%
# Epoch 165, CIFAR-10 Batch 2:  Loss: 0.7429 Validation Accuracy: 58.740002%
# Epoch 165, CIFAR-10 Batch 3:  Loss: 0.6910 Validation Accuracy: 58.520001%
# Epoch 165, CIFAR-10 Batch 4:  Loss: 0.6836 Validation Accuracy: 58.380002%
# Epoch 165, CIFAR-10 Batch 5:  Loss: 0.7146 Validation Accuracy: 58.179998%
# Epoch 166, CIFAR-10 Batch 1:  Loss: 0.7090 Validation Accuracy: 58.219999%
# Epoch 166, CIFAR-10 Batch 2:  Loss: 0.7405 Validation Accuracy: 58.459997%
# Epoch 166, CIFAR-10 Batch 3:  Loss: 0.6871 Validation Accuracy: 58.179998%
# Epoch 166, CIFAR-10 Batch 4:  Loss: 0.6752 Validation Accuracy: 58.279997%
# Epoch 166, CIFAR-10 Batch 5:  Loss: 0.7124 Validation Accuracy: 58.060002%
# Epoch 167, CIFAR-10 Batch 1:  Loss: 0.7206 Validation Accuracy: 58.120000%
# Epoch 167, CIFAR-10 Batch 2:  Loss: 0.7471 Validation Accuracy: 58.499998%
# Epoch 167, CIFAR-10 Batch 3:  Loss: 0.6713 Validation Accuracy: 58.420002%
# Epoch 167, CIFAR-10 Batch 4:  Loss: 0.6792 Validation Accuracy: 58.359998%
# Epoch 167, CIFAR-10 Batch 5:  Loss: 0.7114 Validation Accuracy: 58.420002%
# Epoch 168, CIFAR-10 Batch 1:  Loss: 0.7159 Validation Accuracy: 58.020002%
# Epoch 168, CIFAR-10 Batch 2:  Loss: 0.7401 Validation Accuracy: 58.179998%
# Epoch 168, CIFAR-10 Batch 3:  Loss: 0.6837 Validation Accuracy: 58.560002%
# Epoch 168, CIFAR-10 Batch 4:  Loss: 0.6728 Validation Accuracy: 58.099997%
# Epoch 168, CIFAR-10 Batch 5:  Loss: 0.7114 Validation Accuracy: 58.380002%
# Epoch 169, CIFAR-10 Batch 1:  Loss: 0.7068 Validation Accuracy: 58.260000%
# Epoch 169, CIFAR-10 Batch 2:  Loss: 0.7548 Validation Accuracy: 58.179998%
# Epoch 169, CIFAR-10 Batch 3:  Loss: 0.6756 Validation Accuracy: 58.440000%
# Epoch 169, CIFAR-10 Batch 4:  Loss: 0.6725 Validation Accuracy: 58.060002%
# Epoch 169, CIFAR-10 Batch 5:  Loss: 0.7143 Validation Accuracy: 58.600003%
# Epoch 170, CIFAR-10 Batch 1:  Loss: 0.7102 Validation Accuracy: 57.840002%
# Epoch 170, CIFAR-10 Batch 2:  Loss: 0.7388 Validation Accuracy: 58.340001%
# Epoch 170, CIFAR-10 Batch 3:  Loss: 0.6723 Validation Accuracy: 58.099997%
# Epoch 170, CIFAR-10 Batch 4:  Loss: 0.6717 Validation Accuracy: 58.120000%
# Epoch 170, CIFAR-10 Batch 5:  Loss: 0.7046 Validation Accuracy: 58.260000%
# Epoch 171, CIFAR-10 Batch 1:  Loss: 0.7094 Validation Accuracy: 58.200002%
# Epoch 171, CIFAR-10 Batch 2:  Loss: 0.7404 Validation Accuracy: 58.620000%
# Epoch 171, CIFAR-10 Batch 3:  Loss: 0.6686 Validation Accuracy: 58.120000%
# Epoch 171, CIFAR-10 Batch 4:  Loss: 0.6741 Validation Accuracy: 58.499998%
# Epoch 171, CIFAR-10 Batch 5:  Loss: 0.7073 Validation Accuracy: 58.380002%
# Epoch 172, CIFAR-10 Batch 1:  Loss: 0.7091 Validation Accuracy: 58.179998%
# Epoch 172, CIFAR-10 Batch 2:  Loss: 0.7338 Validation Accuracy: 58.080000%
# Epoch 172, CIFAR-10 Batch 3:  Loss: 0.6772 Validation Accuracy: 58.200002%
# Epoch 172, CIFAR-10 Batch 4:  Loss: 0.6685 Validation Accuracy: 58.160001%
# Epoch 172, CIFAR-10 Batch 5:  Loss: 0.7026 Validation Accuracy: 58.359998%
# Epoch 173, CIFAR-10 Batch 1:  Loss: 0.7155 Validation Accuracy: 58.160001%
# Epoch 173, CIFAR-10 Batch 2:  Loss: 0.7356 Validation Accuracy: 58.420002%
# Epoch 173, CIFAR-10 Batch 3:  Loss: 0.6746 Validation Accuracy: 58.300000%
# Epoch 173, CIFAR-10 Batch 4:  Loss: 0.6753 Validation Accuracy: 58.219999%
# Epoch 173, CIFAR-10 Batch 5:  Loss: 0.7041 Validation Accuracy: 58.120000%
# Epoch 174, CIFAR-10 Batch 1:  Loss: 0.7040 Validation Accuracy: 58.219999%
# Epoch 174, CIFAR-10 Batch 2:  Loss: 0.7462 Validation Accuracy: 58.880001%
# Epoch 174, CIFAR-10 Batch 3:  Loss: 0.6683 Validation Accuracy: 58.099997%
# Epoch 174, CIFAR-10 Batch 4:  Loss: 0.6758 Validation Accuracy: 58.300000%
# Epoch 174, CIFAR-10 Batch 5:  Loss: 0.7044 Validation Accuracy: 58.139998%
# Epoch 175, CIFAR-10 Batch 1:  Loss: 0.7034 Validation Accuracy: 57.959998%
# Epoch 175, CIFAR-10 Batch 2:  Loss: 0.7347 Validation Accuracy: 58.600003%
# Epoch 175, CIFAR-10 Batch 3:  Loss: 0.6701 Validation Accuracy: 58.399999%
# Epoch 175, CIFAR-10 Batch 4:  Loss: 0.6633 Validation Accuracy: 57.859999%
# Epoch 175, CIFAR-10 Batch 5:  Loss: 0.7061 Validation Accuracy: 57.660002%
# Epoch 176, CIFAR-10 Batch 1:  Loss: 0.6962 Validation Accuracy: 58.179998%
# Epoch 176, CIFAR-10 Batch 2:  Loss: 0.7340 Validation Accuracy: 58.620000%
# Epoch 176, CIFAR-10 Batch 3:  Loss: 0.6714 Validation Accuracy: 58.440000%
# Epoch 176, CIFAR-10 Batch 4:  Loss: 0.6710 Validation Accuracy: 57.620001%
# Epoch 176, CIFAR-10 Batch 5:  Loss: 0.6939 Validation Accuracy: 58.160001%
# Epoch 177, CIFAR-10 Batch 1:  Loss: 0.6972 Validation Accuracy: 58.099997%
# Epoch 177, CIFAR-10 Batch 2:  Loss: 0.7213 Validation Accuracy: 58.099997%
# Epoch 177, CIFAR-10 Batch 3:  Loss: 0.6643 Validation Accuracy: 58.279997%
# Epoch 177, CIFAR-10 Batch 4:  Loss: 0.6667 Validation Accuracy: 58.300000%
# Epoch 177, CIFAR-10 Batch 5:  Loss: 0.7039 Validation Accuracy: 58.139998%
# Epoch 178, CIFAR-10 Batch 1:  Loss: 0.6889 Validation Accuracy: 58.279997%
# Epoch 178, CIFAR-10 Batch 2:  Loss: 0.7364 Validation Accuracy: 58.499998%
# Epoch 178, CIFAR-10 Batch 3:  Loss: 0.6678 Validation Accuracy: 58.160001%
# Epoch 178, CIFAR-10 Batch 4:  Loss: 0.6585 Validation Accuracy: 58.099997%
# Epoch 178, CIFAR-10 Batch 5:  Loss: 0.6987 Validation Accuracy: 58.260000%
# Epoch 179, CIFAR-10 Batch 1:  Loss: 0.6924 Validation Accuracy: 58.219999%
# Epoch 179, CIFAR-10 Batch 2:  Loss: 0.7289 Validation Accuracy: 58.179998%
# Epoch 179, CIFAR-10 Batch 3:  Loss: 0.6683 Validation Accuracy: 58.219999%
# Epoch 179, CIFAR-10 Batch 4:  Loss: 0.6615 Validation Accuracy: 58.240002%
# Epoch 179, CIFAR-10 Batch 5:  Loss: 0.6932 Validation Accuracy: 57.840002%
# Epoch 180, CIFAR-10 Batch 1:  Loss: 0.6819 Validation Accuracy: 57.920003%
# Epoch 180, CIFAR-10 Batch 2:  Loss: 0.7284 Validation Accuracy: 58.139998%
# Epoch 180, CIFAR-10 Batch 3:  Loss: 0.6637 Validation Accuracy: 58.160001%
# Epoch 180, CIFAR-10 Batch 4:  Loss: 0.6544 Validation Accuracy: 57.999998%
# Epoch 180, CIFAR-10 Batch 5:  Loss: 0.6966 Validation Accuracy: 57.959998%
# Epoch 181, CIFAR-10 Batch 1:  Loss: 0.6939 Validation Accuracy: 57.999998%
# Epoch 181, CIFAR-10 Batch 2:  Loss: 0.7276 Validation Accuracy: 57.999998%
# Epoch 181, CIFAR-10 Batch 3:  Loss: 0.6581 Validation Accuracy: 58.160001%
# Epoch 181, CIFAR-10 Batch 4:  Loss: 0.6511 Validation Accuracy: 58.020002%
# Epoch 181, CIFAR-10 Batch 5:  Loss: 0.6956 Validation Accuracy: 57.859999%
# Epoch 182, CIFAR-10 Batch 1:  Loss: 0.6846 Validation Accuracy: 57.940000%
# Epoch 182, CIFAR-10 Batch 2:  Loss: 0.7336 Validation Accuracy: 58.539999%
# Epoch 182, CIFAR-10 Batch 3:  Loss: 0.6529 Validation Accuracy: 58.060002%
# Epoch 182, CIFAR-10 Batch 4:  Loss: 0.6559 Validation Accuracy: 57.940000%
# Epoch 182, CIFAR-10 Batch 5:  Loss: 0.6850 Validation Accuracy: 57.760000%
# Epoch 183, CIFAR-10 Batch 1:  Loss: 0.6898 Validation Accuracy: 57.920003%
# Epoch 183, CIFAR-10 Batch 2:  Loss: 0.7268 Validation Accuracy: 58.200002%
# Epoch 183, CIFAR-10 Batch 3:  Loss: 0.6586 Validation Accuracy: 58.459997%
# Epoch 183, CIFAR-10 Batch 4:  Loss: 0.6528 Validation Accuracy: 57.900000%
# Epoch 183, CIFAR-10 Batch 5:  Loss: 0.6930 Validation Accuracy: 58.080000%
# Epoch 184, CIFAR-10 Batch 1:  Loss: 0.6804 Validation Accuracy: 58.160001%
# Epoch 184, CIFAR-10 Batch 2:  Loss: 0.7257 Validation Accuracy: 58.420002%
# Epoch 184, CIFAR-10 Batch 3:  Loss: 0.6543 Validation Accuracy: 58.499998%
# Epoch 184, CIFAR-10 Batch 4:  Loss: 0.6490 Validation Accuracy: 58.060002%
# Epoch 184, CIFAR-10 Batch 5:  Loss: 0.6958 Validation Accuracy: 57.700002%
# Epoch 185, CIFAR-10 Batch 1:  Loss: 0.6793 Validation Accuracy: 57.819998%
# Epoch 185, CIFAR-10 Batch 2:  Loss: 0.7230 Validation Accuracy: 58.260000%
# Epoch 185, CIFAR-10 Batch 3:  Loss: 0.6591 Validation Accuracy: 58.160001%
# Epoch 185, CIFAR-10 Batch 4:  Loss: 0.6596 Validation Accuracy: 58.160001%
# Epoch 185, CIFAR-10 Batch 5:  Loss: 0.6932 Validation Accuracy: 58.219999%
# Epoch 186, CIFAR-10 Batch 1:  Loss: 0.6798 Validation Accuracy: 57.740003%
# Epoch 186, CIFAR-10 Batch 2:  Loss: 0.7234 Validation Accuracy: 58.899999%
# Epoch 186, CIFAR-10 Batch 3:  Loss: 0.6578 Validation Accuracy: 57.999998%
# Epoch 186, CIFAR-10 Batch 4:  Loss: 0.6540 Validation Accuracy: 58.160001%
# Epoch 186, CIFAR-10 Batch 5:  Loss: 0.6884 Validation Accuracy: 57.740003%
# Epoch 187, CIFAR-10 Batch 1:  Loss: 0.6741 Validation Accuracy: 58.260000%
# Epoch 187, CIFAR-10 Batch 2:  Loss: 0.7234 Validation Accuracy: 58.359998%
# Epoch 187, CIFAR-10 Batch 3:  Loss: 0.6518 Validation Accuracy: 58.319998%
# Epoch 187, CIFAR-10 Batch 4:  Loss: 0.6538 Validation Accuracy: 57.900000%
# Epoch 187, CIFAR-10 Batch 5:  Loss: 0.6882 Validation Accuracy: 57.679999%
# Epoch 188, CIFAR-10 Batch 1:  Loss: 0.6761 Validation Accuracy: 58.120000%
# Epoch 188, CIFAR-10 Batch 2:  Loss: 0.7204 Validation Accuracy: 58.260000%
# Epoch 188, CIFAR-10 Batch 3:  Loss: 0.6559 Validation Accuracy: 57.920003%
# Epoch 188, CIFAR-10 Batch 4:  Loss: 0.6515 Validation Accuracy: 58.499998%
# Epoch 188, CIFAR-10 Batch 5:  Loss: 0.6894 Validation Accuracy: 58.020002%
# Epoch 189, CIFAR-10 Batch 1:  Loss: 0.6713 Validation Accuracy: 58.179998%
# Epoch 189, CIFAR-10 Batch 2:  Loss: 0.7166 Validation Accuracy: 58.679998%
# Epoch 189, CIFAR-10 Batch 3:  Loss: 0.6590 Validation Accuracy: 58.080000%
# Epoch 189, CIFAR-10 Batch 4:  Loss: 0.6424 Validation Accuracy: 58.300000%
# Epoch 189, CIFAR-10 Batch 5:  Loss: 0.6918 Validation Accuracy: 58.179998%
# Epoch 190, CIFAR-10 Batch 1:  Loss: 0.6805 Validation Accuracy: 57.900000%
# Epoch 190, CIFAR-10 Batch 2:  Loss: 0.7144 Validation Accuracy: 58.359998%
# Epoch 190, CIFAR-10 Batch 3:  Loss: 0.6534 Validation Accuracy: 57.880002%
# Epoch 190, CIFAR-10 Batch 4:  Loss: 0.6518 Validation Accuracy: 58.359998%
# Epoch 190, CIFAR-10 Batch 5:  Loss: 0.6824 Validation Accuracy: 58.099997%
# Epoch 191, CIFAR-10 Batch 1:  Loss: 0.6803 Validation Accuracy: 58.139998%
# Epoch 191, CIFAR-10 Batch 2:  Loss: 0.7226 Validation Accuracy: 57.900000%
# Epoch 191, CIFAR-10 Batch 3:  Loss: 0.6506 Validation Accuracy: 58.179998%
# Epoch 191, CIFAR-10 Batch 4:  Loss: 0.6511 Validation Accuracy: 57.840002%
# Epoch 191, CIFAR-10 Batch 5:  Loss: 0.6734 Validation Accuracy: 58.279997%
# Epoch 192, CIFAR-10 Batch 1:  Loss: 0.6860 Validation Accuracy: 57.940000%
# Epoch 192, CIFAR-10 Batch 2:  Loss: 0.7081 Validation Accuracy: 58.719999%
# Epoch 192, CIFAR-10 Batch 3:  Loss: 0.6523 Validation Accuracy: 58.080000%
# Epoch 192, CIFAR-10 Batch 4:  Loss: 0.6414 Validation Accuracy: 58.139998%
# Epoch 192, CIFAR-10 Batch 5:  Loss: 0.6855 Validation Accuracy: 57.880002%
# Epoch 193, CIFAR-10 Batch 1:  Loss: 0.6685 Validation Accuracy: 57.620001%
# Epoch 193, CIFAR-10 Batch 2:  Loss: 0.7222 Validation Accuracy: 58.020002%
# Epoch 193, CIFAR-10 Batch 3:  Loss: 0.6397 Validation Accuracy: 58.340001%
# Epoch 193, CIFAR-10 Batch 4:  Loss: 0.6454 Validation Accuracy: 58.060002%
# Epoch 193, CIFAR-10 Batch 5:  Loss: 0.6756 Validation Accuracy: 57.700002%
# Epoch 194, CIFAR-10 Batch 1:  Loss: 0.6727 Validation Accuracy: 57.920003%
# Epoch 194, CIFAR-10 Batch 2:  Loss: 0.7128 Validation Accuracy: 58.399999%
# Epoch 194, CIFAR-10 Batch 3:  Loss: 0.6433 Validation Accuracy: 58.260000%
# Epoch 194, CIFAR-10 Batch 4:  Loss: 0.6418 Validation Accuracy: 58.039999%
# Epoch 194, CIFAR-10 Batch 5:  Loss: 0.6867 Validation Accuracy: 58.120000%
# Epoch 195, CIFAR-10 Batch 1:  Loss: 0.6641 Validation Accuracy: 57.980001%
# Epoch 195, CIFAR-10 Batch 2:  Loss: 0.7112 Validation Accuracy: 58.319998%
# Epoch 195, CIFAR-10 Batch 3:  Loss: 0.6494 Validation Accuracy: 58.300000%
# Epoch 195, CIFAR-10 Batch 4:  Loss: 0.6374 Validation Accuracy: 57.920003%
# Epoch 195, CIFAR-10 Batch 5:  Loss: 0.6798 Validation Accuracy: 57.720000%
# Epoch 196, CIFAR-10 Batch 1:  Loss: 0.6724 Validation Accuracy: 57.660002%
# Epoch 196, CIFAR-10 Batch 2:  Loss: 0.7069 Validation Accuracy: 58.399999%
# Epoch 196, CIFAR-10 Batch 3:  Loss: 0.6508 Validation Accuracy: 58.139998%
# Epoch 196, CIFAR-10 Batch 4:  Loss: 0.6388 Validation Accuracy: 57.679999%
# Epoch 196, CIFAR-10 Batch 5:  Loss: 0.6774 Validation Accuracy: 57.700002%
# Epoch 197, CIFAR-10 Batch 1:  Loss: 0.6667 Validation Accuracy: 58.120000%
# Epoch 197, CIFAR-10 Batch 2:  Loss: 0.7134 Validation Accuracy: 58.260000%
# Epoch 197, CIFAR-10 Batch 3:  Loss: 0.6438 Validation Accuracy: 58.179998%
# Epoch 197, CIFAR-10 Batch 4:  Loss: 0.6483 Validation Accuracy: 57.900000%
# Epoch 197, CIFAR-10 Batch 5:  Loss: 0.6682 Validation Accuracy: 58.020002%
# Epoch 198, CIFAR-10 Batch 1:  Loss: 0.6721 Validation Accuracy: 57.800001%
# Epoch 198, CIFAR-10 Batch 2:  Loss: 0.7067 Validation Accuracy: 58.520001%
# Epoch 198, CIFAR-10 Batch 3:  Loss: 0.6440 Validation Accuracy: 58.380002%
# Epoch 198, CIFAR-10 Batch 4:  Loss: 0.6350 Validation Accuracy: 58.120000%
# Epoch 198, CIFAR-10 Batch 5:  Loss: 0.6740 Validation Accuracy: 58.099997%
# Epoch 199, CIFAR-10 Batch 1:  Loss: 0.6610 Validation Accuracy: 57.840002%
# Epoch 199, CIFAR-10 Batch 2:  Loss: 0.7094 Validation Accuracy: 58.260000%
# Epoch 199, CIFAR-10 Batch 3:  Loss: 0.6322 Validation Accuracy: 58.200002%
# Epoch 199, CIFAR-10 Batch 4:  Loss: 0.6405 Validation Accuracy: 58.300000%
# Epoch 199, CIFAR-10 Batch 5:  Loss: 0.6692 Validation Accuracy: 57.959998%
# Epoch 200, CIFAR-10 Batch 1:  Loss: 0.6646 Validation Accuracy: 57.900000%
# Epoch 200, CIFAR-10 Batch 2:  Loss: 0.6975 Validation Accuracy: 58.600003%
# Epoch 200, CIFAR-10 Batch 3:  Loss: 0.6310 Validation Accuracy: 58.039999%
# Epoch 200, CIFAR-10 Batch 4:  Loss: 0.6337 Validation Accuracy: 57.920003%
# Epoch 200, CIFAR-10 Batch 5:  Loss: 0.6633 Validation Accuracy: 58.060002%

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5762037038803101

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
